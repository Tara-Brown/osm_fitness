# %%
import geopandas as gpd
import pandas as pd

# %%
df = pd.read_csv('geopackages_test/state_53_unified.csv')

# %%
df
# Out:
#      state_fips  placefp       city_name  area_m2_parks  area_m2_parkserve  \
# 0            53    38215          Lamont   5.422190e+03       3.610898e+03
# 1            53    56625         Pullman   1.177570e+06       9.712887e+05
# 2            53    76160          Warden   1.047648e+05       2.909415e+04
# 3            53    47245      Moses Lake   1.752260e+06       1.444498e+06
# 4            53     1010          Albion   2.055837e+04       1.125091e+04
# ..          ...      ...             ...            ...                ...
# 634          53    78780  Wilderness Rim   2.291029e+04       0.000000e+00
# 635          53    78995         Willapa   0.000000e+00       0.000000e+00
# 636          53    79485         Wishram   2.572523e+03       0.000000e+00
# 637          53    79555       Wollochet   6.090797e+05       5.898988e+05
# 638          53    79825     Woods Creek   2.613105e+03       0.000000e+00
#
# ...

# %%
inside = df.trail_length_inside_m.sum()
outside = df.trail_length_outside_m.sum()

# %%
inside/(inside+outside)
# Out:
# 0.1620710092349312

# %%
inside
# Out:
# 3997778.8291390315

# %%
outside
# Out:
# 20669056.08483391
