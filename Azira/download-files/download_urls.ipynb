# %%
import os
import sys
import time
import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
from urllib.parse import urlparse, parse_qs, unquote
import re
import requests
from pathlib import Path

# %%
# ---------------- config ----------------
URLS_FILE = "/mnt/beegfs/hellgate/home/vc149353/osm_fitness/Azira/get-urls/urls.txt"
OUT_DIR = "/mnt/beegfs/hellgate/home/vc149353/azira_downloads"
MAX_WORKERS = 10
TIMEOUT = 60          # seconds per request
RETRIES = 5
CHUNK_SIZE = 1024 * 1024  # 1 MB
# ----------------------------------------

os.makedirs(OUT_DIR, exist_ok=True)
lock = threading.Lock()


def filename_from_url(url):
    qs = parse_qs(urlparse(url).query)
    cd = qs.get("response-content-disposition", [None])[0]
    if not cd:
        return None
    cd = unquote(cd)  # attachment; filename="..."
    m = re.search(r'filename="?([^"]+)"?', cd)
    return m.group(1) if m else None


def download_one(url: str):
    name = filename_from_url(url)
    out_path = os.path.join(OUT_DIR, name)

    if os.path.exists(out_path):
        with lock:
            print(f"[skip] {name}")
        return

    for attempt in range(1, RETRIES + 1):
        try:
            with requests.get(
                url,
                stream=True,
                timeout=TIMEOUT,
                allow_redirects=True,
            ) as r:
                r.raise_for_status()

                # Honor Content-Disposition if present
                cd = r.headers.get("Content-Disposition", "")
                if "filename=" in cd:
                    fname = cd.split("filename=")[-1].strip("\"'")
                    out_path = os.path.join(OUT_DIR, fname)
                    if os.path.exists(out_path):
                        with lock:
                            print(f"[skip] {fname}")
                        return

                tmp = out_path + ".part"
                with open(tmp, "wb") as f:
                    for chunk in r.iter_content(chunk_size=CHUNK_SIZE):
                        if chunk:
                            f.write(chunk)

                os.replace(tmp, out_path)

                with lock:
                    print(f"[ok]   {os.path.basename(out_path)}")
                return

        except Exception as e:
            if attempt == RETRIES:
                with lock:
                    print(f"[FAIL] {name}: {e}")
            else:
                time.sleep(2 ** attempt)


def main():
    if not os.path.exists(URLS_FILE):
        print(f"missing {URLS_FILE}")
        sys.exit(1)

    with open(URLS_FILE) as f:
        urls = [l.strip() for l in f if l.strip()]

    urls = urls[:10]

    if not urls:
        print("no URLs found")
        return

    print(f"Downloading {len(urls)} files with {MAX_WORKERS} threads")

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
        futures = [ex.submit(download_one, url) for url in urls]
        for _ in as_completed(futures):
            pass


#if __name__ == "__main__":
    #main()

# %%
with open(URLS_FILE) as f:
    urls = [l.strip() for l in f if l.strip()]

# %%
for u in urls:
    name = filename_from_url(u)
    out_path = os.path.join(OUT_DIR, name)

    if not os.path.exists(Path(out_path)):
        print(Path(out_path).name)
# Out:
# 10057739_Albuquerque_1_a_New_Mexico_expanded_cel_cdl_report.zip
# 10057739_Albuquerque_1_a_New_Mexico_pin_report.tsv.gz
# 10057738_Albuquerque_1_b_New_Mexico_expanded_cel_cdl_report.zip
# 10057738_Albuquerque_1_b_New_Mexico_pin_report.tsv.gz
# 10057737_Albuquerque_2_a_New_Mexico_expanded_cel_cdl_report.zip
# 10057737_Albuquerque_2_a_New_Mexico_pin_report.tsv.gz
# 10057736_Albuquerque_2_b_New_Mexico_expanded_cel_cdl_report.zip
# 10057736_Albuquerque_2_b_New_Mexico_pin_report.tsv.gz
# 10057735_Henderson_1_a_Nevada_expanded_cel_cdl_report.zip
# 10057735_Henderson_1_a_Nevada_pin_report.tsv.gz
# 10057734_Henderson_1_b_Nevada_expanded_cel_cdl_report.zip
# 10057734_Henderson_1_b_Nevada_pin_report.tsv.gz
# 10057731_Las_Cruces_b_New_Mexico_expanded_cel_cdl_report.zip
# 10057731_Las_Cruces_b_New_Mexico_pin_report.tsv.gz
# 10057730_Las_Cruces_a_New_Mexico_expanded_cel_cdl_report.zip
# 10057730_Las_Cruces_a_New_Mexico_pin_report.tsv.gz
# 10057729_Folsom_a_California_expanded_cel_cdl_report.zip
# 10057729_Folsom_a_California_pin_report.tsv.gz
# 10057728_Folsom_b_California_expanded_cel_cdl_report.zip
# 10057728_Folsom_b_California_pin_report.tsv.gz
# 10057727_San_Jose_2_a_California_expanded_cel_cdl_report.zip
# 10057727_San_Jose_2_a_California_pin_report.tsv.gz
# 10057726_San_Jose_2_b_California_expanded_cel_cdl_report.zip
# 10057726_San_Jose_2_b_California_pin_report.tsv.gz
# 10057725_Norwalk_a_California_expanded_cel_cdl_report.zip
# 10057725_Norwalk_a_California_pin_report.tsv.gz
# 10057724_Norwalk_b_California_expanded_cel_cdl_report.zip
# 10057724_Norwalk_b_California_pin_report.tsv.gz
# 10057723_Temecula_1_a_California_expanded_cel_cdl_report.zip
# 10057723_Temecula_1_a_California_pin_report.tsv.gz
# 10057722_Temecula_1_b_California_expanded_cel_cdl_report.zip
# 10057722_Temecula_1_b_California_pin_report.tsv.gz
# 10057721_Sandy_a_Utah_expanded_cel_cdl_report.zip
# 10057721_Sandy_a_Utah_pin_report.tsv.gz
# 10057720_Sandy_b_Utah_expanded_cel_cdl_report.zip
# 10057720_Sandy_b_Utah_pin_report.tsv.gz
# 10057719_South_Valley_b_New_Mexico_expanded_cel_cdl_report.zip
# 10057719_South_Valley_b_New_Mexico_pin_report.tsv.gz
# 10057718_San_Buenaventura__Ventura__California_expanded_cel_cdl_report.zip
# 10057718_San_Buenaventura__Ventura__California_pin_report.tsv.gz
# 10057717_El_Paso_de_Robles__Paso_Robles__California_expanded_cel_cdl_report.zip
# 10057717_El_Paso_de_Robles__Paso_Robles__California_pin_report.tsv.gz
# 10057716_Los_Angeles_5_California_pin_report.zip
