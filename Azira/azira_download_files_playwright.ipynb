# %%
#from playwright.sync_api import sync_playwright
from playwright.async_api import async_playwright, expect, TimeoutError
import json
from pathlib import Path
import time
from datetime import date, timedelta
import asyncio
from urllib.parse import urljoin
import os
from urllib.parse import urlparse, parse_qs, unquote
import re

# %% [markdown]
# ## 1. Run first - functions and user/pw info

# %%
# login info 
user, pw = 'katrina.mullan@mso.umt.edu', 'wvp6rau6rqb_bwy1EYT!'
url = 'https://pinnacle.azira.com/'


async def start_browser():
    playwright = await async_playwright().start()

    browser = await playwright.chromium.launch(headless=False)

    context = await browser.new_context(
        geolocation={"latitude": 46.8721, "longitude": -113.9940},
        permissions=["geolocation"],
    )

    page = await context.new_page()

    return {
        "playwright": playwright,
        "browser": browser,
        "context": context,
        "page": page,
    }

async def login(page, user, pw):
    await page.goto(url) 
    await page.get_by_role("textbox", name="Email Address").fill(user)
    await page.get_by_role("textbox", name="Password").fill(pw)
    await page.get_by_role("button", name="Log in").click()

    # wait for page load
    await page.wait_for_url("**/home/feeds/datasets**")
    load_more = page.get_by_role("button", name="Load More")
    await load_more.wait_for(state="visible")

# get links on a page

async def get_links(page, restrict_state=None):
    links = []      

    rows = page.locator("table tr")
    row_count = await rows.count()

    for i in range(row_count):
        links_cell = rows.nth(i).locator("td:nth-child(4)")

        # skip empty cells
        if await links_cell.count() == 0:
            continue    

        # get row metadata
        job_id = await rows.nth(i).locator("td:nth-child(1)").inner_text()   
        job_name = await rows.nth(i).locator("td:nth-child(2)").inner_text()

        if restrict_state:
            for name_item in job_name.split("_")[::-1]:
                if not name_item in ['a','b']:
                    state = name_item
                    break
            if state not in restrict_state:
                continue    

        anchors = links_cell.locator("a")
        link_count = await anchors.count()
        for j in range(link_count):
            link = anchors.nth(j)
            text = (await link.inner_text()).strip()   # "Pin Dataset" or "Expanded Standard Dataset"

            if "Pin Dataset" in text or "Expanded Standard" in text:
                text_link = await link.get_attribute("href")
                if text_link:
                    links.append((job_id, job_name, text, text_link))

    return links


# filter for already downloaded files
def filter_downloaded(all_links):

    new_links = []

    for a in all_links:
        filename = filename_from_url(a[3])
        if not Path(f"azira_downloads/{filename}").exists():
            print(f"adding {filename} to download list")
            new_links.append(a)

    return new_links    

def _safe(s: str) -> str:
    return "".join(c if c.isalnum() or c in "._- " else "_" for c in s).strip()

def filename_from_url(url):
    qs = parse_qs(urlparse(url).query)
    cd = qs.get("response-content-disposition", [None])[0]
    if not cd:
        return None
    cd = unquote(cd)  # attachment; filename="..."
    m = re.search(r'filename="?([^"]+)"?', cd)
    return m.group(1) if m else None

async def download_one(context, item, out_dir='azira_downloads', timeout_ms=180_000):
    job_id, job_name, link_text, url = item

    os.makedirs(out_dir, exist_ok=True)

    p = await context.new_page()
    try:
        async with p.expect_download(timeout=timeout_ms) as dl_info:
                    # Direct download URLs won't "navigate" normally. This may raise "Download is starting".
            try:
                await p.goto(url, wait_until="commit")  # minimal wait; doesn't require DOM
            except Exception as e:
                # This is expected for direct downloads
                if "Download is starting" not in str(e):
                    raise

        print(f"Downloading job {job_id} - {job_name} - {link_text}")
        download = await dl_info.value

        # Save with a deterministic filename (optional)
        saved_path = None
        filename = f"{_safe(download.suggested_filename)}"
        saved_path = os.path.join(out_dir, filename)
        await download.save_as(saved_path)
        print(f"Saved to {saved_path}")
        return  saved_path

    finally:
        await p.close()


async def download_three_at_a_time(context, items, out_dir="azira_downloads"):
    sem = asyncio.Semaphore(3)

    async def worker(item):
        async with sem:
            return await download_one(context, item, out_dir=out_dir)

    results = await asyncio.gather(
        *(worker(item) for item in items),
        return_exceptions=True
    )

    completed = []
    failed = []

    for item, result in zip(items, results):
        if isinstance(result, Exception):
            failed.append((item, result))
        else:
            completed.append(result)

    return completed, failed

# %% [markdown]
# ## 2. Login

# %%
# login 
browser_handle = await start_browser()
page = browser_handle["page"]
await login(page, user, pw)

# %% [markdown]
# ## 3. Click "Load More" until the end

# %%
# click "Load More" until the button is no longer visible
from playwright.async_api import expect, TimeoutError as PlaywrightTimeoutError

while True:
    load_more = page.get_by_role("button", name="Load More")

    if await load_more.is_visible():
        await load_more.click()
    else:
        print("end of the line")
        break
    # Wait for new rows to load before next iteration
    await page.wait_for_timeout(1000)
# Out:
# end of the line

# %% [markdown]
# ## 3. Get all links on page (or, from one or more states)

# %%
my_states = ['Colorado', 'Oklahoma', 'Utah', 'California', 'Nevada', "New", "Arizona", "North"]
all_links = await get_links(page, my_states)
new_links = filter_downloaded(all_links)    
new_links
# Out:
# adding 10057358_Morgan_Hill_California_expanded_cel_cdl_report.zip to download list
# adding 10057358_Morgan_Hill_California_pin_report.zip to download list
# adding 10057357_Anaheim_California_expanded_cel_cdl_report.zip to download list
# adding 10057357_Anaheim_California_pin_report.zip to download list
# adding 10057356_Santa_Ana_California_pin_report.zip to download list
# adding 10057356_Santa_Ana_California_expanded_cel_cdl_report.zip to download list
# adding 10057355_Glendale_California_expanded_cel_cdl_report.zip to download list
# adding 10057355_Glendale_California_pin_report.zip to download list
# adding 10057354_Carlsbad_California_expanded_cel_cdl_report.zip to download list
# adding 10057354_Carlsbad_California_pin_report.tsv.gz to download list
# adding 10057353_Davis_California_pin_report.tsv.gz to download list
# adding 10057353_Davis_California_expanded_cel_cdl_report.zip to download list
# adding 10057352_San_Jose_1_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057352_San_Jose_1_a_California_pin_report.tsv.gz to download list
# adding 10057351_San_Jose_1_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057351_San_Jose_1_b_California_pin_report.tsv.gz to download list
# adding 10057350_Simi_Valley_California_expanded_cel_cdl_report.zip to download list
# adding 10057350_Simi_Valley_California_pin_report.tsv.gz to download list
# adding 10057349_Santa_Maria_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057349_Santa_Maria_a_California_pin_report.tsv.gz to download list
# adding 10057348_Santa_Maria_b_California_pin_report.tsv.gz to download list
# adding 10057348_Santa_Maria_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057347_San_Jose_4_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057347_San_Jose_4_a_California_pin_report.zip to download list
# adding 10057346_San_Jose_4_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057346_San_Jose_4_b_California_pin_report.zip to download list
# adding 10057345_Palm_Desert_California_pin_report.tsv.gz to download list
# adding 10057345_Palm_Desert_California_expanded_cel_cdl_report.zip to download list
# adding 10057344_Petaluma_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057344_Petaluma_a_California_pin_report.tsv.gz to download list
# adding 10057343_Petaluma_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057343_Petaluma_b_California_pin_report.tsv.gz to download list
# adding 10057342_Los_Angeles_7_California_pin_report.zip to download list
# adding 10057341_San_Clemente_California_expanded_cel_cdl_report.zip to download list
# adding 10057341_San_Clemente_California_pin_report.tsv.gz to download list
# adding 10057340_Antioch_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057340_Antioch_a_California_pin_report.tsv.gz to download list
# adding 10057339_Antioch_b_California_pin_report.tsv.gz to download list
# adding 10057339_Antioch_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057338_San_Francisco_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057338_San_Francisco_1_California_pin_report.zip to download list
# adding 10057337_Tracy_California_expanded_cel_cdl_report.zip to download list
# adding 10057337_Tracy_California_pin_report.tsv.gz to download list
# adding 10057336_Glendora_California_expanded_cel_cdl_report.zip to download list
# adding 10057336_Glendora_California_pin_report.tsv.gz to download list
# adding 10057335_Concord_California_expanded_cel_cdl_report.zip to download list
# adding 10057335_Concord_California_pin_report.zip to download list
# adding 10057334_Irvine_2_California_expanded_cel_cdl_report.zip to download list
# adding 10057334_Irvine_2_California_pin_report.tsv.gz to download list
# adding 10057333_Lake_Forest_California_expanded_cel_cdl_report.zip to download list
# adding 10057333_Lake_Forest_California_pin_report.zip to download list
# adding 10057332_Santa_Clarita_California_expanded_cel_cdl_report.zip to download list
# adding 10057332_Santa_Clarita_California_pin_report.zip to download list
# adding 10057331_Huntington_Beach_California_expanded_cel_cdl_report.zip to download list
# adding 10057331_Huntington_Beach_California_pin_report.zip to download list
# adding 10057330_Fairfield_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057330_Fairfield_a_California_pin_report.tsv.gz to download list
# adding 10057329_Fairfield_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057329_Fairfield_b_California_pin_report.tsv.gz to download list
# adding 10057328_Santee_California_pin_report.tsv.gz to download list
# adding 10057328_Santee_California_expanded_cel_cdl_report.zip to download list
# adding 10057327_Redding_California_expanded_cel_cdl_report.zip to download list
# adding 10057327_Redding_California_pin_report.tsv.gz to download list
# adding 10057326_Corona_California_expanded_cel_cdl_report.zip to download list
# adding 10057326_Corona_California_pin_report.tsv.gz to download list
# adding 10057325_Lodi_California_expanded_cel_cdl_report.zip to download list
# adding 10057325_Lodi_California_pin_report.tsv.gz to download list
# adding 10057324_Thousand_Oaks_California_expanded_cel_cdl_report.zip to download list
# adding 10057324_Thousand_Oaks_California_pin_report.tsv.gz to download list
# adding 10057323_Burbank_California_expanded_cel_cdl_report.zip to download list
# adding 10057323_Burbank_California_pin_report.zip to download list
# adding 10057322_Antelope_California_expanded_cel_cdl_report.zip to download list
# adding 10057322_Antelope_California_pin_report.zip to download list
# adding 10057321_Pleasanton_California_expanded_cel_cdl_report.zip to download list
# adding 10057321_Pleasanton_California_pin_report.tsv.gz to download list
# adding 10057320_El_Centro_California_expanded_cel_cdl_report.zip to download list
# adding 10057320_El_Centro_California_pin_report.tsv.gz to download list
# adding 10057319_Palo_Alto_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057319_Palo_Alto_a_California_pin_report.tsv.gz to download list
# adding 10057318_Palo_Alto_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057318_Palo_Alto_b_California_pin_report.tsv.gz to download list
# adding 10057317_Novato_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057317_Novato_a_California_pin_report.tsv.gz to download list
# adding 10057316_Novato_b_California_pin_report.tsv.gz to download list
# adding 10057316_Novato_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057315_Los_Banos_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057315_Los_Banos_a_California_pin_report.tsv.gz to download list
# adding 10057314_Los_Banos_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057314_Los_Banos_b_California_pin_report.tsv.gz to download list
# adding 10057313_West_Covina_California_expanded_cel_cdl_report.zip to download list
# adding 10057313_West_Covina_California_pin_report.tsv.gz to download list
# adding 10057312_Paramount_California_expanded_cel_cdl_report.zip to download list
# adding 10057312_Paramount_California_pin_report.zip to download list
# adding 10057311_Oroville_California_expanded_cel_cdl_report.zip to download list
# adding 10057311_Oroville_California_pin_report.tsv.gz to download list
# adding 10057310_Santa_Clara_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057310_Santa_Clara_a_California_pin_report.tsv.gz to download list
# adding 10057309_Santa_Clara_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057309_Santa_Clara_b_California_pin_report.tsv.gz to download list
# adding 10057308_San_Jacinto_California_expanded_cel_cdl_report.zip to download list
# adding 10057308_San_Jacinto_California_pin_report.tsv.gz to download list
# adding 10057307_Santa_Rosa_California_expanded_cel_cdl_report.zip to download list
# adding 10057307_Santa_Rosa_California_pin_report.zip to download list
# adding 10057306_Chula_Vista_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057306_Chula_Vista_1_California_pin_report.zip to download list
# adding 10057305_Escondido_California_expanded_cel_cdl_report.zip to download list
# adding 10057305_Escondido_California_pin_report.zip to download list
# adding 10057304_Bakersfield_2_California_expanded_cel_cdl_report.zip to download list
# adding 10057304_Bakersfield_2_California_pin_report.tsv.gz to download list
# adding 10057303_Irvine_1_California_pin_report.tsv.gz to download list
# adding 10057303_Irvine_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057302_Mill_Valley_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057302_Mill_Valley_a_California_pin_report.tsv.gz to download list
# adding 10057301_Mill_Valley_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057301_Mill_Valley_b_California_pin_report.tsv.gz to download list
# adding 10057300_San_Mateo_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057300_San_Mateo_a_California_pin_report.tsv.gz to download list
# adding 10057299_San_Mateo_b_California_pin_report.tsv.gz to download list
# adding 10057299_San_Mateo_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057298_Encinitas_California_expanded_cel_cdl_report.zip to download list
# adding 10057298_Encinitas_California_pin_report.tsv.gz to download list
# adding 10057297_Live_Oak_California_expanded_cel_cdl_report.zip to download list
# adding 10057297_Live_Oak_California_pin_report.tsv.gz to download list
# adding 10057296_San_Jose_3_California_pin_report.zip to download list
# adding 10057296_San_Jose_3_California_expanded_cel_cdl_report.zip to download list
# adding 10057295_Brentwood_California_expanded_cel_cdl_report.zip to download list
# adding 10057295_Brentwood_California_pin_report.tsv.gz to download list
# adding 10057294_Fullerton_California_expanded_cel_cdl_report.zip to download list
# adding 10057294_Fullerton_California_pin_report.zip to download list
# adding 10057293_San_Marcos_California_expanded_cel_cdl_report.zip to download list
# adding 10057293_San_Marcos_California_pin_report.tsv.gz to download list
# adding 10057292_Rohnert_Park_California_expanded_cel_cdl_report.zip to download list
# adding 10057292_Rohnert_Park_California_pin_report.tsv.gz to download list
# adding 10057291_Chino_California_expanded_cel_cdl_report.zip to download list
# adding 10057291_Chino_California_pin_report.zip to download list
# adding 10057290_El_Segundo_California_expanded_cel_cdl_report.zip to download list
# adding 10057290_El_Segundo_California_pin_report.zip to download list
# adding 10057289_Los_Angeles_6_California_expanded_cel_cdl_report.zip to download list
# adding 10057289_Los_Angeles_6_California_pin_report.zip to download list
# adding 10057288_San_Francisco_2_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057288_San_Francisco_2_a_California_pin_report.zip to download list
# adding 10057287_San_Francisco_2_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057287_San_Francisco_2_b_California_pin_report.zip to download list
# adding 10057286_Bakersfield_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057286_Bakersfield_1_California_pin_report.tsv.gz to download list
# adding 10057285_Salinas_California_expanded_cel_cdl_report.zip to download list
# adding 10057285_Salinas_California_pin_report.zip to download list
# adding 10057284_Monterey_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057284_Monterey_a_California_pin_report.tsv.gz to download list
# adding 10057283_Monterey_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057283_Monterey_b_California_pin_report.tsv.gz to download list
# adding 10057282_Sacramento_2_California_expanded_cel_cdl_report.zip to download list
# adding 10057282_Sacramento_2_California_pin_report.tsv.gz to download list
# adding 10057281_El_Cerrito_California_expanded_cel_cdl_report.zip to download list
# adding 10057281_El_Cerrito_California_pin_report.zip to download list
# adding 10057280_Los_Angeles_2_California_expanded_cel_cdl_report.zip to download list
# adding 10057280_Los_Angeles_2_California_pin_report.zip to download list
# adding 10057279_Los_Angeles_5_California_expanded_cel_cdl_report.zip to download list
# adding 10057278_Carson_California_expanded_cel_cdl_report.zip to download list
# adding 10057278_Carson_California_pin_report.zip to download list
# adding 10057277_Santa_Cruz_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057277_Santa_Cruz_a_California_pin_report.tsv.gz to download list
# adding 10057276_Santa_Cruz_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057276_Santa_Cruz_b_California_pin_report.tsv.gz to download list
# adding 10057275_Oakland_2_California_expanded_cel_cdl_report.zip to download list
# adding 10057275_Oakland_2_California_pin_report.tsv.gz to download list
# adding 10057274_Upland_California_expanded_cel_cdl_report.zip to download list
# adding 10057274_Upland_California_pin_report.zip to download list
# adding 10057273_West_Sacramento_California_expanded_cel_cdl_report.zip to download list
# adding 10057273_West_Sacramento_California_pin_report.zip to download list
# adding 10057272_Murrieta_California_expanded_cel_cdl_report.zip to download list
# adding 10057272_Murrieta_California_pin_report.tsv.gz to download list
# adding 10057271_San_Diego_3_California_pin_report.tsv.gz to download list
# adding 10057271_San_Diego_3_California_expanded_cel_cdl_report.zip to download list
# adding 10057270_Palos_Verdes_Estates_California_pin_report.tsv.gz to download list
# adding 10057270_Palos_Verdes_Estates_California_expanded_cel_cdl_report.zip to download list
# adding 10057269_Torrance_California_expanded_cel_cdl_report.zip to download list
# adding 10057269_Torrance_California_pin_report.zip to download list
# adding 10057268_Chico_California_expanded_cel_cdl_report.zip to download list
# adding 10057268_Chico_California_pin_report.tsv.gz to download list
# adding 10057267_Union_City_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057267_Union_City_a_California_pin_report.tsv.gz to download list
# adding 10057266_Union_City_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057266_Union_City_b_California_pin_report.tsv.gz to download list
# adding 10057265_Hayward_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057265_Hayward_a_California_pin_report.tsv.gz to download list
# adding 10057264_Hayward_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057264_Hayward_b_California_pin_report.tsv.gz to download list
# adding 10057263_Garden_Grove_California_expanded_cel_cdl_report.zip to download list
# adding 10057263_Garden_Grove_California_pin_report.tsv.gz to download list
# adding 10057262_Napa_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057262_Napa_a_California_pin_report.tsv.gz to download list
# adding 10057261_Napa_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057261_Napa_b_California_pin_report.tsv.gz to download list
# adding 10057260_Vacaville_California_expanded_cel_cdl_report.zip to download list
# adding 10057260_Vacaville_California_pin_report.tsv.gz to download list
# adding 10057259_Riverside_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057259_Riverside_1_California_pin_report.zip to download list
# adding 10057258_Oakland_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057258_Oakland_1_California_pin_report.zip to download list
# adding 10057257_Goleta_California_expanded_cel_cdl_report.zip to download list
# adding 10057257_Goleta_California_pin_report.tsv.gz to download list
# adding 10057256_San_Diego_5_California_expanded_cel_cdl_report.zip to download list
# adding 10057256_San_Diego_5_California_pin_report.tsv.gz to download list
# adding 10057255_Manteca_a_California_pin_report.tsv.gz to download list
# adding 10057255_Manteca_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057254_Manteca_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057254_Manteca_b_California_pin_report.tsv.gz to download list
# adding 10057253_Moreno_Valley_California_expanded_cel_cdl_report.zip to download list
# adding 10057253_Moreno_Valley_California_pin_report.tsv.gz to download list
# adding 10057252_San_Diego_4_California_expanded_cel_cdl_report.zip to download list
# adding 10057252_San_Diego_4_California_pin_report.tsv.gz to download list
# adding 10057251_Reedley_California_expanded_cel_cdl_report.zip to download list
# adding 10057251_Reedley_California_pin_report.zip to download list
# adding 10057250_Fresno_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057250_Fresno_1_California_pin_report.zip to download list
# adding 10057249_Fremont_1_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057249_Fremont_1_a_California_pin_report.tsv.gz to download list
# adding 10057248_Fremont_1_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057248_Fremont_1_b_California_pin_report.tsv.gz to download list
# adding 10057247_Moorpark_California_expanded_cel_cdl_report.zip to download list
# adding 10057247_Moorpark_California_pin_report.tsv.gz to download list
# adding 10057246_Greenfield_California_expanded_cel_cdl_report.zip to download list
# adding 10057246_Greenfield_California_pin_report.tsv.gz to download list
# adding 10057245_Rancho_Cucamonga_California_expanded_cel_cdl_report.zip to download list
# adding 10057245_Rancho_Cucamonga_California_pin_report.tsv.gz to download list
# adding 10057244_Rocklin_California_expanded_cel_cdl_report.zip to download list
# adding 10057244_Rocklin_California_pin_report.tsv.gz to download list
# adding 10057243_Woodland_California_expanded_cel_cdl_report.zip to download list
# adding 10057243_Woodland_California_pin_report.zip to download list
# adding 10057242_Turlock_California_expanded_cel_cdl_report.zip to download list
# adding 10057242_Turlock_California_pin_report.zip to download list
# adding 10057241_San_Luis_Obispo_California_expanded_cel_cdl_report.zip to download list
# adding 10057241_San_Luis_Obispo_California_pin_report.tsv.gz to download list
# adding 10057240_Lancaster_California_expanded_cel_cdl_report.zip to download list
# adding 10057240_Lancaster_California_pin_report.tsv.gz to download list
# adding 10057239_Modesto_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057239_Modesto_1_California_pin_report.zip to download list
# adding 10057238_Cupertino_a_California_pin_report.tsv.gz to download list
# adding 10057238_Cupertino_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057237_Cupertino_b_California_pin_report.tsv.gz to download list
# adding 10057237_Cupertino_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057236_Los_Angeles_3_California_expanded_cel_cdl_report.zip to download list
# adding 10057236_Los_Angeles_3_California_pin_report.zip to download list
# adding 10057235_Orange_California_expanded_cel_cdl_report.zip to download list
# adding 10057235_Orange_California_pin_report.zip to download list
# adding 10057234_Irvine_3_California_expanded_cel_cdl_report.zip to download list
# adding 10057234_Irvine_3_California_pin_report.zip to download list
# adding 10057233_Clovis_California_expanded_cel_cdl_report.zip to download list
# adding 10057233_Clovis_California_pin_report.zip to download list
# adding 10057232_Ridgecrest_California_expanded_cel_cdl_report.zip to download list
# adding 10057232_Ridgecrest_California_pin_report.tsv.gz to download list
# adding 10057231_Laguna_Hills_California_expanded_cel_cdl_report.zip to download list
# adding 10057231_Laguna_Hills_California_pin_report.tsv.gz to download list
# adding 10057230_San_Diego_2_California_expanded_cel_cdl_report.zip to download list
# adding 10057230_San_Diego_2_California_pin_report.zip to download list
# adding 10057229_Chino_Hills_California_expanded_cel_cdl_report.zip to download list
# adding 10057229_Chino_Hills_California_pin_report.tsv.gz to download list
# adding 10057228_Vallejo_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057228_Vallejo_a_California_pin_report.tsv.gz to download list
# adding 10057227_Vallejo_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057227_Vallejo_b_California_pin_report.tsv.gz to download list
# adding 10057226_Laguna_Niguel_California_expanded_cel_cdl_report.zip to download list
# adding 10057226_Laguna_Niguel_California_pin_report.zip to download list
# adding 10057225_Eastvale_California_expanded_cel_cdl_report.zip to download list
# adding 10057225_Eastvale_California_pin_report.zip to download list
# adding 10057224_Richmond_California_expanded_cel_cdl_report.zip to download list
# adding 10057224_Richmond_California_pin_report.zip to download list
# adding 10057223_Roseville_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057223_Roseville_1_California_pin_report.tsv.gz to download list
# adding 10057222_Victorville_California_expanded_cel_cdl_report.zip to download list
# adding 10057222_Victorville_California_pin_report.zip to download list
# adding 10057221_Menifee_California_expanded_cel_cdl_report.zip to download list
# adding 10057221_Menifee_California_pin_report.tsv.gz to download list
# adding 10057220_Alameda_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057220_Alameda_a_California_pin_report.tsv.gz to download list
# adding 10057219_Alameda_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057219_Alameda_b_California_pin_report.tsv.gz to download list
# adding 10057218_Delano_California_expanded_cel_cdl_report.zip to download list
# adding 10057218_Delano_California_pin_report.zip to download list
# adding 10057217_Whittier_California_expanded_cel_cdl_report.zip to download list
# adding 10057217_Whittier_California_pin_report.zip to download list
# adding 10057216_Fresno_2_California_expanded_cel_cdl_report.zip to download list
# adding 10057216_Fresno_2_California_pin_report.zip to download list
# adding 10057215_Mission_Viejo_California_expanded_cel_cdl_report.zip to download list
# adding 10057215_Mission_Viejo_California_pin_report.tsv.gz to download list
# adding 10057214_Indio_California_expanded_cel_cdl_report.zip to download list
# adding 10057214_Indio_California_pin_report.zip to download list
# adding 10057213_Santa_Monica_California_expanded_cel_cdl_report.zip to download list
# adding 10057213_Santa_Monica_California_pin_report.zip to download list
# adding 10057212_Oxnard_California_expanded_cel_cdl_report.zip to download list
# adding 10057212_Oxnard_California_pin_report.zip to download list
# adding 10057211_San_Bernardino_California_expanded_cel_cdl_report.zip to download list
# adding 10057211_San_Bernardino_California_pin_report.tsv.gz to download list
# adding 10057210_Citrus_Heights_California_expanded_cel_cdl_report.zip to download list
# adding 10057210_Citrus_Heights_California_pin_report.zip to download list
# adding 10057209_San_Ramon_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057209_San_Ramon_a_California_pin_report.tsv.gz to download list
# adding 10057208_San_Ramon_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057208_San_Ramon_b_California_pin_report.tsv.gz to download list
# adding 10057207_Los_Angeles_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057207_Los_Angeles_1_California_pin_report.zip to download list
# adding 10057206_Beaumont_California_expanded_cel_cdl_report.zip to download list
# adding 10057206_Beaumont_California_pin_report.tsv.gz to download list
# adding 10057205_Visalia_California_expanded_cel_cdl_report.zip to download list
# adding 10057205_Visalia_California_pin_report.zip to download list
# adding 10057204_Sacramento_3_California_expanded_cel_cdl_report.zip to download list
# adding 10057204_Sacramento_3_California_pin_report.zip to download list
# adding 10057203_Monterey_Park_California_expanded_cel_cdl_report.zip to download list
# adding 10057203_Monterey_Park_California_pin_report.zip to download list
# adding 10057202_Long_Beach_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057202_Long_Beach_1_California_pin_report.zip to download list
# adding 10057201_Redwood_City_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057201_Redwood_City_a_California_pin_report.tsv.gz to download list
# adding 10057200_Redwood_City_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057200_Redwood_City_b_California_pin_report.tsv.gz to download list
# adding 10057199_San_Diego_1_California_expanded_cel_cdl_report.zip to download list
# adding 10057199_San_Diego_1_California_pin_report.tsv.gz to download list
# adding 10057198_Stockton_California_expanded_cel_cdl_report.zip to download list
# adding 10057198_Stockton_California_pin_report.zip to download list
# adding 10057197_Santa_Barbara_California_expanded_cel_cdl_report.zip to download list
# adding 10057197_Santa_Barbara_California_pin_report.tsv.gz to download list
# adding 10057196_Sunnyvale_a_California_expanded_cel_cdl_report.zip to download list
# adding 10057196_Sunnyvale_a_California_pin_report.tsv.gz to download list
# adding 10057195_Sunnyvale_b_California_expanded_cel_cdl_report.zip to download list
# adding 10057195_Sunnyvale_b_California_pin_report.tsv.gz to download list
# adding 10057194_Los_Angeles_4_California_expanded_cel_cdl_report.zip to download list
# adding 10057194_Los_Angeles_4_California_pin_report.zip to download list
# adding 10057193_San_Diego_6_California_expanded_cel_cdl_report.zip to download list
# adding 10057193_San_Diego_6_California_pin_report.zip to download list
# adding 10057192_Fontana_California_expanded_cel_cdl_report.zip to download list
# adding 10057192_Fontana_California_pin_report.tsv.gz to download list
# adding 10057191_Watsonville_California_expanded_cel_cdl_report.zip to download list
# adding 10057191_Watsonville_California_pin_report.tsv.gz to download list
# adding 10057190_Ontario_California_expanded_cel_cdl_report.zip to download list
# adding 10057190_Ontario_California_pin_report.tsv.gz to download list
# adding 10057189_La_Mesa_California_expanded_cel_cdl_report.zip to download list
# adding 10057189_La_Mesa_California_pin_report.zip to download list
# adding 10057188_Pasadena_California_expanded_cel_cdl_report.zip to download list
# adding 10057188_Pasadena_California_pin_report.zip to download list
# adding 10057187_Elk_Grove_1_California_expanded_cel_cdl_report.zip to download list
# adding 10
California',
#   'Pin Dataset',
#   'https://insights-api-prod-us-west-2-report.s3.amazonaws.com/reports/10057184/pin_report/10057184_Livermore_California_pin_report.zip?response-content-disposition=attachment%3B%20filename%3D%2210057184_Livermore_California_pin_report.zip%22&response-content-type=application%2Fx-gzip&AWSAccessKeyId=AKIASOM5CCFUB76XXDHE&Signature=c9ZaxBs5nW5kNlWGZaRMfyzpMqw%3D&Expires=1767050657'),
#  ('10057183',
#   'Newport_Beach_California',
#   'Expanded Standard Dataset',
#   'https://insights-api-prod-us-west-2-report.s3.amazonaws.com/reports/10057183/expanded_cel_cdl_report/10057183_Newport_Beach_California_expanded_cel_cdl_report.zip?response-content-disposition=attachment%3B%20filename%3D%2210057183_Newport_Beach_California_expanded_cel_cdl_report.zip%22&response-content-type=application%2Fx-gzip&AWSAccessKeyId=AKIASOM5CCFUB76XXDHE&Signature=ohFP%2BtW1Qiup7ATVYNa1GloQABo%3D&Expires=1767051631'),
#  ('10057183',
#   'Newport_Beach_California',
#   'Pin Dataset',
#   'https://insights-api-prod-us-west-2-report.s3.amazonaws.com/reports/10057183/pin_report/10057183_Newport_Beach_California_pin_report.tsv.gz?response-content-disposition=attachment%3B%20filename%3D%2210057183_Newport_Beach_California_pin_report.tsv.gz%22&response-content-type=application%2Fx-gzip&AWSAccessKeyId=AKIASOM5CCFUB76XXDHE&Signature=TlUNOgUWBnX0EDMNNb9%2BJxkw6Sg%3D&Expires=1767051071'),
#  ('10057182',
#   'Arcata_California',
#   'Expanded Standard Dataset',
#   'https://insights-api-prod-us-west-2-report.s3.amazonaws.com/reports/10057182/expanded_cel_cdl_report/10057182_Arcata_California_expanded_cel_cdl_report.zip?response-content-disposition=attachment%3B%20filename%3D%2210057182_Arcata_California_expanded_cel_cdl_report.zip%22&response-content-type=application%2Fx-gzip&AWSAccessKeyId=AKIASOM5CCFUB76XXDHE&Signature=4r6gK1UHsEfC7w2DJ6Kpo%2BPmRXc%3D&Expires=1767051266'),
#  ('10057182',
#   'Arcata_California',
#   'Pin Dataset',
#   'https://insights-api-prod-us-west-2-report.s3.amazonaws.com/reports/10057182/pin_report/10057182_Arcata_California_pin_report.tsv.gz?response-content-disposition=attachment%3B%20filename%3D%2210057182_Arcata_California_pin_report.tsv.gz%22&response-content-type=application%2Fx-gzip&AWSAccessKeyId=AKIASOM5CCFUB76XXDHE&Signature=lQkydf6vWvaIaJfdnEarOLwqxUM%3D&Expires=1767050959')]

# %% [markdown]
# ## 4. Download links

# %%
completed, failed = await download_three_at_a_time(
    page.context,
    new_links,
    out_dir="azira_downloads"
)

print("Completed:", len(completed))
print("Failed:", len(failed))
# Out:
# Completed: 96
# Failed: 0

# %% [markdown]
# ## Fix Colorado

# %%
download_list = []

base_dir = Path('/home/vince/Documents/SmartFires/osm_fitness')
folders = [p for p in base_dir.iterdir() if p.is_dir()]

# ----REMOVE NEXT LINE TO DO ALL STATES-----
folders = [f for f in folders if 'Colorado' in f.name]

for folder in folders:  
    geojson_files = list(folder.glob('*.geojson'))
    for json_path in geojson_files:
        download_list.append(json_path)
# Out:
# [PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Denver_5.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Centennial_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Denver_4.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Commerce City.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Arvada_2.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Lakewood_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Denver_3.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Superior.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Aurora_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Greeley.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Colorado Springs_2.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Golden.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Denver_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Alamosa.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Fountain.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Littleton.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Fort Collins_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Air Force Academy.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Grand Junction.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Boulder.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Broomfield_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Frederick.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Arvada_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Steamboat Springs.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Thornton_2.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Aspen.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Colorado Springs_3.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Colorado Springs_4.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Greenwood Village.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Durango.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Thornton_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Wheat Ridge.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Westminster_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Parker.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Highlands Ranch.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Pueblo.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Longmont.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Denver_2.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Aurora_2.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Erie.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Colorado Springs_1.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Aurora_3.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Loveland.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Castle Rock.geojson'),
#  PosixPath('/home/vince/Documents/SmartFires/osm_fitness/Colorado_700k(45)/Brighton.geojson')]

# %%
all_links = await get_links(page, "Colorado")

# %%
requested = list(set(["_".join(a[1].split("_")[:-1]) for a in all_links]))

# %%
jsons = [i.stem for i in download_list]
