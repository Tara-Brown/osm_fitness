# %%
import osmnx as ox
import pandas as pd
import time
import requests
import os
from pathlib import Path
from datetime import datetime

# %% [markdown]
#  # 1. Get list of all US Counties
#
# The attempt to download data for a very large county - Los Angeles - was successful.
#
# Now, i will attempt to obtain a list of all US Counties...
#
# I should be able to get this data from the US Census API Geography Endpoint: https://www.census.gov/data/developers/data-sets/geo-info.html

# %%
census_api_key = " 349179f9505abb551eb4de4ab998d2a0f58d06aa"

# %%
url = 'https://api.census.gov/data/2023/geoinfo'

# needed! 
headers = {'User-Agent': 'Mozilla/5.0'}

params = {'get':'NAME', 
                        'for': 'county:*',
                      }

response = requests.get(url, headers=headers, params=params, timeout=10)

if response.status_code == 200:
    data = response.json()
    print("Success")
else:
    print(response.status_code)
# Out:
# Success

# %% [markdown]
# Convert to a Pandas dataframe

# %%
# extract county names
counties_list = [item[0] for item in data][1:]

counties_df = pd.DataFrame(counties_list, columns=['name_full'])

# add State column 
counties_df['state'] = counties_df.apply(lambda x: x['name_full'].split(",")[1].strip(), axis=1)
# add Counties
counties_df['county'] = counties_df.apply(lambda x: x['name_full'].split(",")[0].strip(), axis=1)

counties_df.head()
# Out:
#                  name_full    state          county
# 0  Autauga County, Alabama  Alabama  Autauga County
# 1  Baldwin County, Alabama  Alabama  Baldwin County
# 2  Barbour County, Alabama  Alabama  Barbour County
# 3     Bibb County, Alabama  Alabama     Bibb County
# 4   Blount County, Alabama  Alabama   Blount County

# %% [markdown]
# ### Save the County names to file

# %%
counties_df.to_csv('us_counties.csv', index = False)

# %% [markdown]
# # 2. Download all US Counies

# %%
counties_df = pd.read_csv('us_counties.csv')

# df for results
results_df = pd.DataFrame(columns = ['state', 'name_full', 'name_abbrev', 'downloaded', 'file_path', 'size', 'date', 'area'])

# %%
counties_df.head()
# Out:
#                  name_full    state          county
# 0  Autauga County, Alabama  Alabama  Autauga County
# 1  Baldwin County, Alabama  Alabama  Baldwin County
# 2  Barbour County, Alabama  Alabama  Barbour County
# 3     Bibb County, Alabama  Alabama     Bibb County
# 4   Blount County, Alabama  Alabama   Blount County

# %%
def get_abbrev_name(county_row):
    county = county_row['name_full'].split(",")[0]

    # remove 'County' suffix
    suffix_loc = county.find("County")

    if suffix_loc != -1:
        county = county[:suffix_loc].strip()
    
    return county

# %%
import requests
import geopandas as gpd
from shapely.ops import unary_union
from shapely.geometry import shape
import pandas as pd
from datetime import datetime

# ---- configure ----
base_url = "https://server7.tplgis.org/arcgis7/rest/services/ParkServe/ParkServe_ProdNew/MapServer/2/query" # replace with your URL
base_condition = "(park_designation = 'LP' OR park_designation = 'LREC')"

# fields, format, page size
out_fields = "*"   # or list of fields you need
page_size = 1000   # how many features to request per page (tune for the service)
equal_area_crs = "EPSG:5070"   # Conterminous US Albers (good for US-wide comparisons)

# list of counties to query (string names). You can take these from your counties_df
counties = counties_df['name_full'].unique().tolist()

def fetch_features_for_county(full_name):
    """Fetch all features for a county (pages) and return a list of GeoJSON geometries (dict)"""
    features = []
    offset = 0
    county, state = [s.strip() for s in full_name.split(",")]
    while True:
        where_clause = f"Park_County = '{county.strip()}' AND park_state = '{state.strip()}' AND {base_condition}"
        params = {
            "where": where_clause,
            "outFields": out_fields,
            "f": "geojson",
            "resultOffset": offset,
            "resultRecordCount": page_size,
        }
        r = requests.get(base_url, params=params, timeout=60)
        r.raise_for_status()
        gj = r.json()

        # geojson feature collection -> features list
        page_features = gj.get("features", [])
        if not page_features:
            break

        features.extend(page_features)

        # If the server returns less than page_size we are done;
        # Some ArcGIS services set "exceededTransferLimit": true — in many cases this
        # means you must page using resultOffset until no more features returned.
        if len(page_features) < page_size:
            break
        offset += page_size

    return features

def area_for_features_geojson(features_geojson, equal_area_crs=equal_area_crs):
    """Given a list of GeoJSON features (dicts), compute union area in m^2 efficiently."""
    if not features_geojson:
        return 0.0

    # Build a GeoSeries of geometries (avoid heavy attribute copying)
    geoms = [shape(feat["geometry"]) for feat in features_geojson if feat.get("geometry")]

    if not geoms:
        return 0.0
    
    gsf = gpd.GeoSeries(geoms)
    
    # ensure CRS is set before transforming
    if gsf.crs is None:
        gsf = gsf.set_crs("EPSG:4326")

    # Some features may be invalid; attempt a quick fix (buffer(0)) lazily
    # quick geometry fix if needed
    if not gsf.is_valid.all():
        gsf = gsf.buffer(0)
    # Reproject to equal-area CRS once and unary_union
    gsf_proj = gsf.to_crs(equal_area_crs)
    union_geom = unary_union(gsf_proj.values)   # single unioned geometry
    area_m2 = float(union_geom.area) if union_geom is not None else 0.0
    return area_m2

# ---- main loop: do one county at a time to limit memory ----
rows = []
for county in counties:
    try:
        features = fetch_features_for_county(county)
        area_m2 = area_for_features_geojson(features)
        rows.append({"county": county, "area_m2": area_m2})
    except Exception as e:
        print(f"ERROR fetching {county}: {e}")
        rows.append({"county": county, "area_m2": float('nan')})

# final tidy DataFrame
area_df = pd.DataFrame(rows)
area_df = area_df.sort_values("area_m2", ascending=False).reset_index(drop=True)
print(area_df.head())

# optional: merge with your counties_df for additional fields
# merged = counties_df.merge(area_df, left_on="name_full", right_on="county", how="left")

# %%
area_df.head(20)
# Out:
#                              county       area_m2
# 0           Collier County, Florida  2.361040e+09
# 1          Maricopa County, Arizona  4.099900e+08
# 2    Los Angeles County, California  3.201923e+08
# 3    Santa Clara County, California  3.031208e+08
# 4      San Diego County, California  2.616306e+08
# 5              Harris County, Texas  2.178562e+08
# 6              Pima County, Arizona  2.054264e+08
# 7           King County, Washington  1.902062e+08
# 8        Davidson County, Tennessee  1.783267e+08
# 9              Dallas County, Texas  1.526676e+08
# 10         Fairfax County, Virginia  1.216868e+08
# 11     Hillsborough County, Florida  1.216024e+08
# 12       Alameda County, California  1.184512e+08
# 13            Franklin County, Ohio  1.166680e+08
# 14  Contra Costa County, California  1.159665e+08
# 15        Orange County, California  1.156945e+08
# 16             Travis County, Texas  1.154835e+08
# 17            Tarrant County, Texas  1.090739e+08
# 18   Allegheny County, Pennsylvania  1.081874e+08
# 19         Suffolk County, New York  1.036415e+08

# %%
print(f"total area: {area_df['area_m2'].sum()}")
# Out:
# total area: 15991018528.014133

# %%
import requests
import geopandas as gpd
from shapely.geometry import shape
import pandas as pd
from datetime import datetime

# --- Config ---
equal_area_crs = "EPSG:5070"  # Equal-area CRS for area calculations
today = datetime.today().strftime("%Y-%m-%d")

# Census TIGER base URLs (official)
COUNTY_URL = "https://www2.census.gov/geo/tiger/TIGER2025/COUNTY/tl_2025_us_county.zip"
PLACE_BASE_URL = "https://www2.census.gov/geo/tiger/TIGER2025/PLACE/tl_2025_{statefp}_place.zip"

# ParkServe endpoint
PARKSERVE_URL = "https://server7.tplgis.org/arcgis7/rest/services/ParkServe/ParkServe_ProdNew/MapServer/2/query"
PARKSERVE_CONDITION = "(park_designation = 'LP' OR park_designation = 'LREC')"

# --- Load all counties (nationwide shapefile) ---
print("Loading counties...")
counties_gdf = gpd.read_file(COUNTY_URL).to_crs("EPSG:4326")

# Create readable columns
counties_gdf["statefp"] = counties_gdf["STATEFP"]
counties_gdf["countyfp"] = counties_gdf["COUNTYFP"]
counties_gdf["geoid"] = counties_gdf["GEOID"]
counties_gdf["county_name"] = counties_gdf["NAME"]
counties_gdf["name_full"] = (
    counties_gdf["county_name"] + ", " + counties_gdf["STATEFP"].map(str)
)
counties_gdf = counties_gdf.to_crs(equal_area_crs)

# --- Load all cities ("places") ---
print("Loading city shapefiles by state...")
state_fips_list = counties_gdf["statefp"].unique().tolist()

city_gdfs = []
for fips in state_fips_list:
    url = PLACE_BASE_URL.format(statefp=fips.zfill(2))
    try:
        gdf = gpd.read_file(url)
        gdf["statefp"] = fips
        gdf = gdf.to_crs(equal_area_crs)
        city_gdfs.append(gdf)
    except Exception as e:
        print(f"  ⚠️ Failed to load {url}: {e}")

cities_gdf = pd.concat(city_gdfs, ignore_index=True)
print(f"Loaded {len(cities_gdf)} city polygons across {len(state_fips_list)} states.")

# --- ParkServe helper function ---
def fetch_features_for_county(county_name, state_fips):
    """Fetch ParkServe parks by county and state FIPS"""
    features = []
    offset = 0
    while True:
        where_clause = (
            f"Park_State_FIPS = '{state_fips}' AND Park_County = '{county_name} County' AND {PARKSERVE_CONDITION}"
        )
        params = {
            "where": where_clause,
            "outFields": "*",
            "f": "geojson",
            "resultOffset": offset,
            "resultRecordCount": 1000,
        }
        r = requests.get(PARKSERVE_URL, params=params, timeout=60)
        r.raise_for_status()
        gj = r.json()
        page_features = gj.get("features", [])
        if not page_features:
            break
        features.extend(page_features)
        if len(page_features) < 1000:
            break
        offset += 1000
    return features


def parks_within_cities(features_geojson, city_gdf):
    """Intersect ParkServe features with city boundaries and sum area within them."""
    if not features_geojson:
        return 0.0

    parks = gpd.GeoDataFrame(
        geometry=[shape(f["geometry"]) for f in features_geojson if f.get("geometry")],
        crs="EPSG:4326",
    ).to_crs(equal_area_crs)

    # Fix invalid geometries
    parks["geometry"] = parks.buffer(0)
    parks = parks[~parks.geometry.is_empty]

    # Intersect with cities (same CRS)
    parks_in_cities = gpd.overlay(parks, city_gdf, how="intersection")

    if parks_in_cities.empty:
        return 0.0

    # Compute total area (in m²)
    return float(parks_in_cities.geometry.area.sum())


# --- Main loop ---
rows = []
for _, row in counties_gdf.iterrows():
    county_name = row["county_name"]
    state_fips = row["statefp"]
    geoid = row["geoid"]

    print(f"Processing {county_name} (state FIPS {state_fips})...")

    try:
        features = fetch_features_for_county(county_name, state_fips)

        # Get all cities within this county geometry
        county_geom = row["geometry"]
        cities_in_county = cities_gdf[cities_gdf.intersects(county_geom)]

        area_m2 = parks_within_cities(features, cities_in_county)
        rows.append(
            {
                "county": county_name,
                "state_fips": state_fips,
                "county_fips": row["countyfp"],
                "geoid": geoid,
                "area_m2_citybounded": area_m2,
                "date": today,
            }
        )

        print(f"  → area within cities = {area_m2:,.1f} m²")

    except Exception as e:
        print(f"  ❌ ERROR processing {county_name}: {e}")
        rows.append(
            {
                "county": county_name,
                "state_fips": state_fips,
                "county_fips": row["countyfp"],
                "geoid": geoid,
                "area_m2_citybounded": float("nan"),
                "date": today,
            }
        )

# --- Results ---
bounded_area_df = pd.DataFrame(rows).sort_values("area_m2_citybounded", ascending=False)
print("\nTop 5 counties by park area within cities:")
print(bounded_area_df.head())
# Out:
# Loading counties...
# Loading city shapefiles by state...
# Loaded 32629 city polygons across 56 states.
# Processing Kiowa (state FIPS 40)...
#   → area within cities = 208,671.6 m²
# Processing Lake (state FIPS 46)...
#   → area within cities = 295,319.2 m²
# Processing Caswell (state FIPS 37)...
#   → area within cities = 59,291.8 m²
# Processing Presidio (state FIPS 48)...
#   → area within cities = 70,501.7 m²
# Processing Greene (state FIPS 39)...
#   → area within cities = 6,266,808.3 m²
# Processing Willacy (state FIPS 48)...
#   → area within cities = 126,703.1 m²
# Processing Bayamón (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Los Alamos (state FIPS 35)...
#   → area within cities = 1,202,611.8 m²
# Processing Choctaw (state FIPS 40)...
#   → area within cities = 79,772.6 m²
# Processing Dickinson (state FIPS 20)...
#   → area within cities = 376,041.8 m²
# Processing Starr (state FIPS 48)...
#   → area within cities = 262,273.8 m²
# Processing Effingham (state FIPS 13)...
#   → area within cities = 318,353.1 m²
# Processing Roger Mills (state FIPS 40)...
#   → area within cities = 0.0 m²
# Processing Richland (state FIPS 55)...
#   → area within cities = 861,518.4 m²
# Processing Lea (state FIPS 35)...
#   → area within cities = 2,444,939.8 m²
# Processing Lamar (state FIPS 01)...
#   → area within cities = 0.0 m²
# Processing Florida (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Marshall (state FIPS 47)...
#   → area within cities = 697,105.8 m²
# Processing Appomattox (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Madison (state FIPS 05)...
#   → area within cities = 0.0 m²
# Processing St. Charles (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Poinsett (state FIPS 05)...
#   → area within cities = 231,208.8 m²
# Processing Gulf (state FIPS 12)...
#   → area within cities = 475,166.3 m²
# Processing Hamblen (state FIPS 47)...
#   → area within cities = 1,346,008.4 m²
# Processing Ballard (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Archer (state FIPS 48)...
#   → area within cities = 95,507.9 m²
# Processing Baylor (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing San Augustine (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Storey (state FIPS 32)...
#   → area within cities = 0.0 m²
# Processing Schley (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Madison (state FIPS 48)...
#   → area within cities = 750,128.1 m²
# Processing San Joaquin (state FIPS 06)...
#   → area within cities = 10,421,634.8 m²
# Processing Winston (state FIPS 28)...
#   → area within cities = 184,099.6 m²
# Processing Henry (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Mercer (state FIPS 21)...
#   → area within cities = 36,162.1 m²
# Processing Wheeler (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Lewis (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Grant (state FIPS 27)...
#   → area within cities = 0.0 m²
# Processing Humphreys (state FIPS 28)...
#   → area within cities = 102,765.3 m²
# Processing Clarke (state FIPS 01)...
#   → area within cities = 272,646.3 m²
# Processing Chase (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Trigg (state FIPS 21)...
#   → area within cities = 79,493.0 m²
# Processing Jasper (state FIPS 19)...
#   → area within cities = 636,693.8 m²
# Processing Wayne (state FIPS 28)...
#   → area within cities = 208,589.5 m²
# Processing Cottle (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Greensville (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Polk (state FIPS 12)...
#   → area within cities = 13,524,118.6 m²
# Processing Young (state FIPS 48)...
#   → area within cities = 557,025.9 m²
# Processing Tallapoosa (state FIPS 01)...
#   → area within cities = 905,537.7 m²
# Processing Rockingham (state FIPS 33)...
#   → area within cities = 2,407,255.2 m²
# Processing Rio Grande (state FIPS 08)...
#   → area within cities = 82,929.5 m²
# Processing Plymouth (state FIPS 19)...
#   → area within cities = 919,581.2 m²
# Processing Yates (state FIPS 36)...
#   → area within cities = 188,937.9 m²
# Processing King (state FIPS 53)...
#   → area within cities = 109,584,454.0 m²
# Processing Deschutes (state FIPS 41)...
#   → area within cities = 3,090,527.3 m²
# Processing Pottawattamie (state FIPS 19)...
#   → area within cities = 4,700,122.1 m²
# Processing Christian (state FIPS 29)...
#   → area within cities = 665,600.0 m²
# Processing Ciales (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Lamar (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Ripley (state FIPS 18)...
#   → area within cities = 749,252.6 m²
# Processing Mercer (state FIPS 38)...
#   → area within cities = 244,295.7 m²
# Processing Hart (state FIPS 13)...
#   → area within cities = 197,908.5 m²
# Processing Jackson (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Northumberland (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Fort Bend (state FIPS 48)...
#   → area within cities = 32,899,882.0 m²
# Processing Green Lake (state FIPS 55)...
#   → area within cities = 176,512.5 m²
# Processing Pondera (state FIPS 30)...
#   → area within cities = 170,760.6 m²
# Processing Walworth (state FIPS 55)...
#   → area within cities = 3,045,002.5 m²
# Processing Mineral (state FIPS 32)...
#   → area within cities = 0.0 m²
# Processing Howard (state FIPS 18)...
#   → area within cities = 1,608,426.0 m²
# Processing Pike (state FIPS 18)...
#   → area within cities = 0.0 m²
# Processing Christian (state FIPS 21)...
#   → area within cities = 1,130,347.5 m²
# Processing Eaton (state FIPS 26)...
#   → area within cities = 2,948,132.3 m²
# Processing Wapello (state FIPS 19)...
#   → area within cities = 1,713,178.6 m²
# Processing Imperial (state FIPS 06)...
#   → area within cities = 1,437,382.0 m²
# Processing Cass (state FIPS 26)...
#   → area within cities = 392,429.2 m²
# Processing Bristol (state FIPS 44)...
#   → area within cities = 0.0 m²
# Processing Bosque (state FIPS 48)...
#   → area within cities = 331,589.8 m²
# Processing Newport (state FIPS 44)...
#   → area within cities = 561,604.1 m²
# Processing Fairfield (state FIPS 39)...
#   → area within cities = 5,558,895.5 m²
# Processing Pierce (state FIPS 38)...
#   → area within cities = 60,805.7 m²
# Processing Carroll (state FIPS 17)...
#   → area within cities = 29,408.7 m²
# Processing Red Lake (state FIPS 27)...
#   → area within cities = 0.0 m²
# Processing Jefferson (state FIPS 41)...
#   → area within cities = 371,907.1 m²
# Processing Cheatham (state FIPS 47)...
#   → area within cities = 1,164,440.5 m²
# Processing McCone (state FIPS 30)...
#   → area within cities = 0.0 m²
# Processing Buchanan (state FIPS 19)...
#   → area within cities = 325,099.9 m²
# Processing DuPage (state FIPS 17)...
#   → area within cities = 29,064,867.9 m²
# Processing Fall River (state FIPS 46)...
#   → area within cities = 193,998.5 m²
# Processing Kittson (state FIPS 27)...
#   → area within cities = 0.0 m²
# Processing Oconee (state FIPS 13)...
#   → area within cities = 226,997.8 m²
# Processing Wilson (state FIPS 48)...
#   → area within cities = 230,929.2 m²
# Processing Fillmore (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Madison (state FIPS 12)...
#   → area within cities = 136,210.2 m²
# Processing Carolina (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Sullivan (state FIPS 18)...
#   → area within cities = 154,068.7 m²
# Processing La Paz (state FIPS 04)...
#   → area within cities = 125,695.5 m²
# Processing Brooks (state FIPS 13)...
#   → area within cities = 82,648.4 m²
# Processing Aleutians West (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Kodiak Island (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Stafford (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Telfair (state FIPS 13)...
#   → area within cities = 23,547.4 m²
# Processing Monroe (state FIPS 26)...
#   → area within cities = 1,986,843.3 m²
# Processing White (state FIPS 18)...
#   → area within cities = 216,405.1 m²
# Processing Noble (state FIPS 18)...
#   → area within cities = 1,646,077.6 m²
# Processing Greene (state FIPS 13)...
#   → area within cities = 24,765.8 m²
# Processing Buffalo (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Mellette (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Ector (state FIPS 48)...
#   → area within cities = 2,389,663.0 m²
# Processing Limestone (state FIPS 48)...
#   → area within cities = 301,646.1 m²
# Processing Grays Harbor (state FIPS 53)...
#   → area within cities = 2,467,203.1 m²
# Processing Berkeley (state FIPS 54)...
#   → area within cities = 225,634.2 m²
# Processing Villalba (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Park (state FIPS 30)...
#   → area within cities = 222,763.8 m²
# Processing Denton (state FIPS 48)...
#   → area within cities = 43,882,198.8 m²
# Processing Cherokee (state FIPS 45)...
#   → area within cities = 91,920.0 m²
# Processing Yancey (state FIPS 37)...
#   → area within cities = 0.0 m²
# Processing Red River (state FIPS 48)...
#   → area within cities = 97,952.2 m²
# Processing Matagorda (state FIPS 48)...
#   → area within cities = 513,184.5 m²
# Processing Stevens (state FIPS 27)...
#   → area within cities = 1,182,250.1 m²
# Processing Warren (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Hardeman (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Monroe (state FIPS 17)...
#   → area within cities = 1,391,015.8 m²
# Processing Jenkins (state FIPS 13)...
#   → area within cities = 74,594.4 m²
# Processing Grayson (state FIPS 21)...
#   → area within cities = 511,467.3 m²
# Processing Palo Pinto (state FIPS 48)...
#   → area within cities = 986,842.5 m²
# Processing Heard (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Lawrence (state FIPS 01)...
#   → area within cities = 210,986.8 m²
# Processing Guaynabo (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Marshall (state FIPS 28)...
#   → area within cities = 54,449.9 m²
# Processing Clark (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Haskell (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Bienville (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Walker (state FIPS 13)...
#   → area within cities = 328,854.1 m²
# Processing Wilkin (state FIPS 27)...
#   → area within cities = 229,140.5 m²
# Processing Randolph (state FIPS 17)...
#   → area within cities = 835,472.1 m²
# Processing Kennebec (state FIPS 23)...
#   → area within cities = 1,341,639.0 m²
# Processing Smyth (state FIPS 51)...
#   → area within cities = 56,406.3 m²
# Processing Roosevelt (state FIPS 35)...
#   → area within cities = 805,849.8 m²
# Processing Somerset (state FIPS 42)...
#   → area within cities = 1,489,655.4 m²
# Processing Washington (state FIPS 51)...
#   → area within cities = 158,219.5 m²
# Processing Guilford (state FIPS 37)...
#   → area within cities = 19,222,333.8 m²
# Processing Ada (state FIPS 16)...
#   → area within cities = 13,225,220.3 m²
# Processing Custer (state FIPS 40)...
#   → area within cities = 1,942,666.7 m²
# Processing Marion (state FIPS 39)...
#   → area within cities = 801,129.3 m²
# Processing Pike (state FIPS 17)...
#   → area within cities = 83,170.5 m²
# Processing Woodford (state FIPS 17)...
#   → area within cities = 723,964.6 m²
# Processing Richmond (state FIPS 13)...
#   → area within cities = 3,020,416.7 m²
# Processing Vigo (state FIPS 18)...
#   → area within cities = 1,496,379.6 m²
# Processing Elkhart (state FIPS 18)...
#   → area within cities = 4,642,152.3 m²
# Processing Grayson (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Lubbock (state FIPS 48)...
#   → area within cities = 11,574,174.2 m²
# Processing Meeker (state FIPS 27)...
#   → area within cities = 727,515.0 m²
# Processing Kittitas (state FIPS 53)...
#   → area within cities = 1,433,747.3 m²
# Processing Randolph (state FIPS 18)...
#   → area within cities = 607,448.5 m²
# Processing Kane (state FIPS 49)...
#   → area within cities = 108,137.5 m²
# Processing Pennington (state FIPS 27)...
#   → area within cities = 313,233.9 m²
# Processing Whatcom (state FIPS 53)...
#   → area within cities = 13,338,509.2 m²
# Processing Gilliam (state FIPS 41)...
#   → area within cities = 0.0 m²
# Processing Ocean (state FIPS 34)...
#   → area within cities = 15,319,775.5 m²
# Processing Boone (state FIPS 05)...
#   → area within cities = 313,859.5 m²
# Processing Comanche (state FIPS 40)...
#   → area within cities = 2,779,551.0 m²
# Processing Jones (state FIPS 48)...
#   → area within cities = 1,715,699.8 m²
# Processing Grimes (state FIPS 48)...
#   → area within cities = 171,689.9 m²
# Processing Genesee (state FIPS 26)...
#   → area within cities = 6,120,333.8 m²
# Processing Assumption (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Calhoun (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Greene (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Dallas (state FIPS 29)...
#   → area within cities = 124,579.8 m²
# Processing Pittsylvania (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Denali (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Pawnee (state FIPS 20)...
#   → area within cities = 504,119.6 m²
# Processing Wyandotte (state FIPS 20)...
#   → area within cities = 10,924,499.2 m²
# Processing Dixie (state FIPS 12)...
#   → area within cities = 17,752.4 m²
# Processing Tuscola (state FIPS 26)...
#   → area within cities = 543,430.5 m²
# Processing Southeast Fairbanks (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Graham (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing St. Landry (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Giles (state FIPS 47)...
#   → area within cities = 262,803.4 m²
# Processing Lucas (state FIPS 39)...
#   → area within cities = 17,139,305.6 m²
# Processing Mississippi (state FIPS 05)...
#   → area within cities = 809,812.8 m²
# Processing Rincón (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Grenada (state FIPS 28)...
#   → area within cities = 201,754.3 m²
# Processing Simpson (state FIPS 21)...
#   → area within cities = 689,318.8 m²
# Processing Grand Isle (state FIPS 50)...
#   → area within cities = 0.0 m²
# Processing Columbiana (state FIPS 39)...
#   → area within cities = 1,586,963.2 m²
# Processing Nelson (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Osceola (state FIPS 12)...
#   → area within cities = 3,399,734.8 m²
# Processing Grant (state FIPS 05)...
#   → area within cities = 149,949.5 m²
# Processing DeKalb (state FIPS 18)...
#   → area within cities = 1,152,745.9 m²
# Processing Ouachita (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing St. John the Baptist (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing St. Helena (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Schuyler (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Franklin (state FIPS 01)...
#   → area within cities = 622,827.1 m²
# Processing Carroll (state FIPS 21)...
#   → area within cities = 74,367.2 m²
# Processing Clear Creek (state FIPS 08)...
#   → area within cities = 0.0 m²
# Processing Kimble (state FIPS 48)...
#   → area within cities = 104,521.9 m²
# Processing Clay (state FIPS 46)...
#   → area within cities = 377,184.5 m²
# Processing Sussex (state FIPS 10)...
#   → area within cities = 1,322,768.0 m²
# Processing Jasper (state FIPS 13)...
#   → area within cities = 102,540.0 m²
# Processing Randolph (state FIPS 29)...
#   → area within cities = 2,010,726.8 m²
# Processing Butler (state FIPS 20)...
#   → area within cities = 1,263,135.1 m²
# Processing Hays (state FIPS 48)...
#   → area within cities = 11,801,633.7 m²
# Processing Cowlitz (state FIPS 53)...
#   → area within cities = 2,206,094.2 m²
# Processing Live Oak (state FIPS 48)...
#   → area within cities = 29,624.9 m²
# Processing Hooker (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Prince Edward (state FIPS 51)...
#   → area within cities = 47,861.5 m²
# Processing Carbon (state FIPS 49)...
#   → area within cities = 455,280.6 m²
# Processing Bucks (state FIPS 42)...
#   → area within cities = 7,317,174.6 m²
# Processing Hand (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Lycoming (state FIPS 42)...
#   → area within cities = 1,119,434.7 m²
# Processing Latah (state FIPS 16)...
#   → area within cities = 246,007.1 m²
# Processing Putnam (state FIPS 13)...
#   → area within cities = 96,957.4 m²
# Processing Galax (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Quay (state FIPS 35)...
#   → area within cities = 774,629.5 m²
# Processing King (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Lafayette (state FIPS 05)...
#   → area within cities = 0.0 m²
# Processing Tom Green (state FIPS 48)...
#   → area within cities = 4,333,806.7 m²
# Processing Butler (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing St. John (state FIPS 78)...
#   → area within cities = 0.0 m²
# Processing Campbell (state FIPS 56)...
#   → area within cities = 4,403,445.6 m²
# Processing Morgan (state FIPS 13)...
#   → area within cities = 198,067.5 m²
# Processing Cross (state FIPS 05)...
#   → area within cities = 291,098.0 m²
# Processing Phillips (state FIPS 05)...
#   → area within cities = 279,912.4 m²
# Processing St. James (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing St. Thomas (state FIPS 78)...
#   → area within cities = 0.0 m²
# Processing Dubuque (state FIPS 19)...
#   → area within cities = 3,391,754.7 m²
# Processing Goochland (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Sherman (state FIPS 20)...
#   → area within cities = 145,956.7 m²
# Processing Richland (state FIPS 39)...
#   → area within cities = 1,611,804.3 m²
# Processing Adams (state FIPS 17)...
#   → area within cities = 2,402,006.5 m²
# Processing Champaign (state FIPS 39)...
#   → area within cities = 510,417.2 m²
# Processing Sullivan (state FIPS 33)...
#   → area within cities = 1,588,698.6 m²
# Processing Iroquois (state FIPS 17)...
#   → area within cities = 364,519.1 m²
# Processing Poweshiek (state FIPS 19)...
#   → area within cities = 854,830.2 m²
# Processing Wayne (state FIPS 39)...
#   → area within cities = 2,484,817.3 m²
# Processing Fayette (state FIPS 13)...
#   → area within cities = 2,489,399.3 m²
# Processing Hancock (state FIPS 13)...
#   → area within cities = 1,392.0 m²
# Processing Kendall (state FIPS 48)...
#   → area within cities = 1,697,581.2 m²
# Processing Greene (state FIPS 36)...
#   → area within cities = 378,470.9 m²
# Processing Orange (state FIPS 51)...
#   → area within cities = 198,456.1 m²
# Processing McCurtain (state FIPS 40)...
#   → area within cities = 217,409.9 m²
# Processing Tift (state FIPS 13)...
#   → area within cities = 267,260.2 m²
# Processing Cass (state FIPS 31)...
#   → area within cities = 345,892.0 m²
# Processing Kingsbury (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Converse (state FIPS 56)...
#   → area within cities = 170,011.0 m²
# Processing Herkimer (state FIPS 36)...
#   → area within cities = 1,698,984.3 m²
# Processing Logan (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Gogebic (state FIPS 26)...
#   → area within cities = 55,000.9 m²
# Processing Becker (state FIPS 27)...
#   → area within cities = 446,429.8 m²
# Processing Marshall (state FIPS 01)...
#   → area within cities = 1,605,011.8 m²
# Processing Wilkinson (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Yakutat (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Sheridan (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Leake (state FIPS 28)...
#   → area within cities = 209,187.4 m²
# Processing Caguas (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Camuy (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Clay (state FIPS 28)...
#   → area within cities = 360,784.0 m²
# Processing Franklin (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Vega Alta (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Boone (state FIPS 19)...
#   → area within cities = 1,167,461.4 m²
# Processing Polk (state FIPS 48)...
#   → area within cities = 1,360,190.9 m²
# Processing Dixon (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Harford (state FIPS 24)...
#   → area within cities = 6,205,045.1 m²
# Processing Edgefield (state FIPS 45)...
#   → area within cities = 166,087.4 m²
# Processing Accomack (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Union (state FIPS 47)...
#   → area within cities = 0.0 m²
# Processing Mineral (state FIPS 54)...
#   → area within cities = 43,012.9 m²
# Processing Ashland (state FIPS 55)...
#   → area within cities = 712,348.1 m²
# Processing Ford (state FIPS 17)...
#   → area within cities = 228,686.0 m²
# Processing Emmons (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Shasta (state FIPS 06)...
#   → area within cities = 2,634,435.6 m²
# Processing Vermilion (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Randolph (state FIPS 05)...
#   → area within cities = 261,029.0 m²
# Processing Oneida (state FIPS 55)...
#   → area within cities = 66,643.9 m²
# Processing East Carroll (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing East Feliciana (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing St. Bernard (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Wharton (state FIPS 48)...
#   → area within cities = 1,095,319.2 m²
# Processing Prince of Wales-Hyder (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Petersburg (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Floyd (state FIPS 48)...
#   → area within cities = 137,766.4 m²
# Processing Wrangell (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Madison (state FIPS 21)...
#   → area within cities = 1,273,581.9 m²
# Processing Brunswick (state FIPS 51)...
#   → area within cities = 35,738.2 m²
# Processing Dyer (state FIPS 47)...
#   → area within cities = 480,404.0 m²
# Processing Gibson (state FIPS 47)...
#   → area within cities = 1,158,744.2 m²
# Processing Prince George (state FIPS 51)...
#   → area within cities = 38,230.7 m²
# Processing Lawrence (state FIPS 05)...
#   → area within cities = 399,068.5 m²
# Processing Eddy (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Pierce (state FIPS 53)...
#   → area within cities = 26,557,887.1 m²
# Processing Sagadahoc (state FIPS 23)...
#   → area within cities = 397,755.3 m²
# Processing Sweet Grass (state FIPS 30)...
#   → area within cities = 0.0 m²
# Processing Grayson (state FIPS 48)...
#   → area within cities = 5,237,166.7 m²
# Processing Greene (state FIPS 42)...
#   → area within cities = 801,018.7 m²
# Processing Northwest Arctic (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Ellis (state FIPS 20)...
#   → area within cities = 731,714.0 m²
# Processing Hale (state FIPS 01)...
#   → area within cities = 52,493.7 m²
# Processing Perry (state FIPS 01)...
#   → area within cities = 0.0 m²
# Processing Colbert (state FIPS 01)...
#   → area within cities = 597,997.4 m²
# Processing Pratt (state FIPS 20)...
#   → area within cities = 629,846.5 m²
# Processing Bourbon (state FIPS 21)...
#   → area within cities = 525,073.5 m²
# Processing Rutherford (state FIPS 47)...
#   → area within cities = 4,818,785.6 m²
# Processing Cook (state FIPS 13)...
#   → area within cities = 86,863.5 m²
# Processing Lane (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Harper (state FIPS 40)...
#   → area within cities = 0.0 m²
# Processing Piatt (state FIPS 17)...
#   → area within cities = 32,454.9 m²
# Processing Crosby (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Baca (state FIPS 08)...
#   → area within cities = 0.0 m²
# Processing Boundary (state FIPS 16)...
#   → area within cities = 61,424.3 m²
# Processing Bear Lake (state FIPS 16)...
#   → area within cities = 0.0 m²
# Processing Union (state FIPS 39)...
#   → area within cities = 1,673,589.0 m²
# Processing Cuyahoga (state FIPS 39)...
#   → area within cities = 92,230,965.3 m²
# Processing Lavaca (state FIPS 48)...
#   → area within cities = 1,542,423.5 m²
# Processing Nowata (state FIPS 40)...
#   → area within cities = 82,987.3 m²
# Processing Glascock (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Umatilla (state FIPS 41)...
#   → area within cities = 1,007,159.7 m²
# Processing Oglala Lakota (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Matanuska-Susitna (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Delaware (state FIPS 18)...
#   → area within cities = 1,578,580.1 m²
# Processing Levy (state FIPS 12)...
#   → area within cities = 374,363.4 m²
# Processing Gurabo (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Hatillo (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Hancock (state FIPS 28)...
#   → area within cities = 173,765.5 m²
# Processing Wilcox (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Red River (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Knox (state FIPS 47)...
#   → area within cities = 9,511,349.1 m²
# Processing Oxford (state FIPS 23)...
#   → area within cities = 303,727.0 m²
# Processing Norfolk (state FIPS 25)...
#   → area within cities = 14,996,729.1 m²
# Processing Hendricks (state FIPS 18)...
#   → area within cities = 4,638,696.5 m²
# Processing Jackson (state FIPS 17)...
#   → area within cities = 616,164.5 m²
# Processing Georgetown (state FIPS 45)...
#   → area within cities = 545,441.6 m²
# Processing Hettinger (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Grand (state FIPS 49)...
#   → area within cities = 114,917.8 m²
# Processing Tooele (state FIPS 49)...
#   → area within cities = 3,601,294.1 m²
# Processing Hampton (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Buffalo (state FIPS 55)...
#   → area within cities = 0.0 m²
# Processing Frederick (state FIPS 51)...
#   → area within cities = 61,362.5 m²
# Processing Lewis (state FIPS 54)...
#   → area within cities = 12,733.5 m²
# Processing Polk (state FIPS 27)...
#   → area within cities = 767,398.1 m²
# Processing Redwood (state FIPS 27)...
#   → area within cities = 956,184.2 m²
# Processing Fayette (state FIPS 47)...
#   → area within cities = 0.0 m²
# Processing Swains Island (state FIPS 60)...
#   → area within cities = 0.0 m²
# Processing Lincoln (state FIPS 41)...
#   → area within cities = 555,245.1 m²
# Processing York (state FIPS 23)...
#   → area within cities = 2,455,915.0 m²
# Processing Codington (state FIPS 46)...
#   → area within cities = 1,835,513.6 m²
# Processing Pike (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Stewart (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Monmouth (state FIPS 34)...
#   → area within cities = 14,509,693.2 m²
# Processing Clay (state FIPS 05)...
#   → area within cities = 392,500.3 m²
# Processing Faulkner (state FIPS 05)...
#   → area within cities = 1,056,193.4 m²
# Processing Delaware (state FIPS 40)...
#   → area within cities = 288,006.2 m²
# Processing Keokuk (state FIPS 19)...
#   → area within cities = 0.0 m²
# Processing Greene (state FIPS 17)...
#   → area within cities = 608,669.8 m²
# Processing Lake (state FIPS 27)...
#   → area within cities = 113,888.0 m²
# Processing Troup (state FIPS 13)...
#   → area within cities = 2,018,261.6 m²
# Processing Humboldt (state FIPS 06)...
#   → area within cities = 2,919,853.8 m²
# Processing Dickson (state FIPS 47)...
#   → area within cities = 681,703.3 m²
# Processing Raleigh (state FIPS 54)...
#   → area within cities = 568,351.1 m²
# Processing Chaves (state FIPS 35)...
#   → area within cities = 1,495,030.4 m²
# Processing Santa Fe (state FIPS 35)...
#   → area within cities = 2,960,574.2 m²
# Processing Orange (state FIPS 06)...
#   → area within cities = 93,470,513.9 m²
# Processing Santa Cruz (state FIPS 04)...
#   → area within cities = 314,981.3 m²
# Processing Currituck (state FIPS 37)...
#   → area within cities = 0.0 m²
# Processing Lawrence (state FIPS 17)...
#   → area within cities = 196,660.5 m²
# Processing Webster (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Hancock (state FIPS 17)...
#   → area within cities = 215,769.8 m²
# Processing Hutchinson (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Crook (state FIPS 41)...
#   → area within cities = 547,694.9 m²
# Processing Franklin (state FIPS 50)...
#   → area within cities = 334,711.1 m²
# Processing Marquette (state FIPS 26)...
#   → area within cities = 2,016,657.0 m²
# Processing Davidson (state FIPS 37)...
#   → area within cities = 694,956.5 m²
# Processing Clay (state FIPS 17)...
#   → area within cities = 30,505.8 m²
# Processing Knox (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Livingston (state FIPS 29)...
#   → area within cities = 347,737.8 m²
# Processing Tioga (state FIPS 42)...
#   → area within cities = 800,082.1 m²
# Processing Dakota (state FIPS 31)...
#   → area within cities = 1,157,748.5 m²
# Processing Leelanau (state FIPS 26)...
#   → area within cities = 96,740.6 m²
# Processing Surry (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Moniteau (state FIPS 29)...
#   → area within cities = 350,820.5 m²
# Processing Westmoreland (state FIPS 51)...
#   → area within cities = 51,852.6 m²
# Processing Yadkin (state FIPS 37)...
#   → area within cities = 154,761.8 m²
# Processing Merced (state FIPS 06)...
#   → area within cities = 2,665,523.1 m²
# Processing Dewey (state FIPS 40)...
#   → area within cities = 0.0 m²
# Processing Burke (state FIPS 37)...
#   → area within cities = 2,560,706.2 m²
# Processing Wayne (state FIPS 37)...
#   → area within cities = 1,204,799.6 m²
# Processing Warren (state FIPS 42)...
#   → area within cities = 1,037,519.7 m²
# Processing Howard (state FIPS 05)...
#   → area within cities = 220,524.4 m²
# Processing Davie (state FIPS 37)...
#   → area within cities = 104,274.1 m²
# Processing McDowell (state FIPS 37)...
#   → area within cities = 89,532.7 m²
# Processing Nevada (state FIPS 05)...
#   → area within cities = 93,922.0 m²
# Processing Yuma (state FIPS 08)...
#   → area within cities = 55,918.1 m²
# Processing Sherman (state FIPS 48)...
#   → area within cities = 36,844.2 m²
# Processing Uvalde (state FIPS 48)...
#   → area within cities = 1,008,280.7 m²
# Processing Auglaize (state FIPS 39)...
#   → area within cities = 1,012,382.9 m²
# Processing Bossier (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Emmet (state FIPS 19)...
#   → area within cities = 416,194.1 m²
# Processing Saline (state FIPS 20)...
#   → area within cities = 2,227,341.0 m²
# Processing Magoffin (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Bailey (state FIPS 48)...
#   → area within cities = 586,377.3 m²
# Processing Callaway (state FIPS 29)...
#   → area within cities = 854,110.1 m²
# Processing Albany (state FIPS 56)...
#   → area within cities = 879,453.1 m²
# Processing Park (state FIPS 56)...
#   → area within cities = 686,409.7 m²
# Processing Montour (state FIPS 42)...
#   → area within cities = 157,561.2 m²
# Processing Queens (state FIPS 36)...
#   → area within cities = 22,878,006.8 m²
# Processing Suwannee (state FIPS 12)...
#   → area within cities = 224,171.9 m²
# Processing Cheboygan (state FIPS 26)...
#   → area within cities = 196,756.3 m²
# Processing Randolph (state FIPS 01)...
#   → area within cities = 131,717.7 m²
# Processing Ashe (state FIPS 37)...
#   → area within cities = 33,959.7 m²
# Processing Dolores (state FIPS 08)...
#   → area within cities = 0.0 m²
# Processing Licking (state FIPS 39)...
#   → area within cities = 3,995,965.9 m²
# Processing Manassas (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Union (state FIPS 05)...
#   → area within cities = 292,743.0 m²
# Processing Henderson (state FIPS 17)...
#   → area within cities = 7,749.7 m²
# Processing Montgomery (state FIPS 01)...
#   → area within cities = 3,983,854.1 m²
# Processing Arapahoe (state FIPS 08)...
#   → area within cities = 40,031,338.9 m²
# Processing Marion (state FIPS 21)...
#   → area within cities = 115,459.9 m²
# Processing Holmes (state FIPS 28)...
#   → area within cities = 86,715.2 m²
# Processing Oktibbeha (state FIPS 28)...
#   → area within cities = 752,748.5 m²
# Processing Ceiba (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Corozal (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Fergus (state FIPS 30)...
#   → area within cities = 229,935.9 m²
# Processing Garrett (state FIPS 24)...
#   → area within cities = 497,529.7 m²
# Processing Webster (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Hillsdale (state FIPS 26)...
#   → area within cities = 280,739.0 m²
# Processing Logan (state FIPS 21)...
#   → area within cities = 248,123.8 m²
# Processing Custer (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Merrimack (state FIPS 33)...
#   → area within cities = 2,005,502.9 m²
# Processing York (state FIPS 42)...
#   → area within cities = 3,145,452.1 m²
# Processing Rutherford (state FIPS 37)...
#   → area within cities = 864,658.0 m²
# Processing Beadle (state FIPS 46)...
#   → area within cities = 486,334.6 m²
# Processing Cullman (state FIPS 01)...
#   → area within cities = 684,816.8 m²
# Processing Douglas (state FIPS 13)...
#   → area within cities = 1,702,389.6 m²
# Processing Johnson (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Washington (state FIPS 37)...
#   → area within cities = 93,581.5 m²
# Processing Jones (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Ray (state FIPS 29)...
#   → area within cities = 315,381.5 m²
# Processing Hocking (state FIPS 39)...
#   → area within cities = 170,536.9 m²
# Processing Lowndes (state FIPS 01)...
#   → area within cities = 0.0 m²
# Processing Candler (state FIPS 13)...
#   → area within cities = 120,317.0 m²
# Processing Linn (state FIPS 19)...
#   → area within cities = 9,790,657.5 m²
# Processing Trinity (state FIPS 06)...
#   → area within cities = 0.0 m²
# Processing Muscogee (state FIPS 13)...
#   → area within cities = 9,074,580.3 m²
# Processing Tallahatchie (state FIPS 28)...
#   → area within cities = 5,944.5 m²
# Processing Atchison (state FIPS 20)...
#   → area within cities = 1,246,266.6 m²
# Processing Lares (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Douglas (state FIPS 17)...
#   → area within cities = 340,653.7 m²
# Processing Greene (state FIPS 51)...
#   → area within cities = 54,501.4 m²
# Processing Guam (state FIPS 66)...
#   → area within cities = 0.0 m²
# Processing Waushara (state FIPS 55)...
#   → area within cities = 147,469.4 m²
# Processing Izard (state FIPS 05)...
#   → area within cities = 0.0 m²
# Processing Monterey (state FIPS 06)...
#   → area within cities = 15,614,557.5 m²
# Processing Grant (state FIPS 35)...
#   → area within cities = 476,100.9 m²
# Processing Miller (state FIPS 29)...
#   → area within cities = 220,620.9 m²
# Processing Wilkes (state FIPS 37)...
#   → area within cities = 714,602.9 m²
# Processing Juneau (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Decatur (state FIPS 13)...
#   → area within cities = 1,714,837.1 m²
# Processing Wayne (state FIPS 18)...
#   → area within cities = 1,909,271.9 m²
# Processing Barren (state FIPS 21)...
#   → area within cities = 459,931.5 m²
# Processing Howard (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Dunn (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Amador (state FIPS 06)...
#   → area within cities = 405,315.4 m²
# Processing Fentress (state FIPS 47)...
#   → area within cities = 0.0 m²
# Processing Coffey (state FIPS 20)...
#   → area within cities = 134,412.4 m²
# Processing Branch (state FIPS 26)...
#   → area within cities = 736,438.3 m²
# Processing Pierce (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Bleckley (state FIPS 13)...
#   → area within cities = 121,128.4 m²
# Processing Burke (state FIPS 13)...
#   → area within cities = 75,598.8 m²
# Processing Union (state FIPS 17)...
#   → area within cities = 194,977.4 m²
# Processing Kankakee (state FIPS 17)...
#   → area within cities = 3,565,518.0 m²
# Processing McIntosh (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Platte (state FIPS 31)...
#   → area within cities = 1,012,913.5 m²
# Processing Warren (state FIPS 37)...
#   → area within cities = 0.0 m²
# Processing Aibonito (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Marion (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Fauquier (state FIPS 51)...
#   → area within cities = 552,671.5 m²
# Processing Radford (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Douglas (state FIPS 32)...
#   → area within cities = 822,917.3 m²
# Processing Franklin (state FIPS 12)...
#   → area within cities = 184,093.6 m²
# Processing Greene (state FIPS 18)...
#   → area within cities = 182,437.1 m²
# Processing Rush (state FIPS 18)...
#   → area within cities = 354,970.1 m²
# Processing Washington (state FIPS 55)...
#   → area within cities = 7,235,517.4 m²
# Processing Laclede (state FIPS 29)...
#   → area within cities = 369,994.6 m²
# Processing Mercer (state FIPS 42)...
#   → area within cities = 1,037,898.9 m²
# Processing Linn (state FIPS 41)...
#   → area within cities = 3,090,571.2 m²
# Processing Lafayette (state FIPS 55)...
#   → area within cities = 0.0 m²
# Processing Washington (state FIPS 40)...
#   → area within cities = 1,254,352.6 m²
# Processing Preston (state FIPS 54)...
#   → area within cities = 78,993.0 m²
# Processing Rota (state FIPS 69)...
#   → area within cities = 0.0 m²
# Processing Waupaca (state FIPS 55)...
#   → area within cities = 2,456,045.0 m²
# Processing Edwards (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Lake (state FIPS 41)...
#   → area within cities = 10,126.5 m²
# Processing Ozark (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Dickinson (state FIPS 19)...
#   → area within cities = 263,164.1 m²
# Processing Harlan (state FIPS 21)...
#   → area within cities = 259,541.3 m²
# Processing Geary (state FIPS 20)...
#   → area within cities = 1,140,646.2 m²
# Processing Berks (state FIPS 42)...
#   → area within cities = 6,767,411.4 m²
# Processing Carter (state FIPS 47)...
#   → area within cities = 501,032.3 m²
# Processing Lyon (state FIPS 27)...
#   → area within cities = 583,388.8 m²
# Processing Charlotte (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Washington (state FIPS 47)...
#   → area within cities = 2,943,634.2 m²
# Processing Newberry (state FIPS 45)...
#   → area within cities = 273,856.0 m²
# Processing Isle of Wight (state FIPS 51)...
#   → area within cities = 993,262.7 m²
# Processing Wheeler (state FIPS 41)...
#   → area within cities = 0.0 m²
# Processing Butler (state FIPS 29)...
#   → area within cities = 570,063.6 m²
# Processing Iberville (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Sharkey (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Lunenburg (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Traill (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Hall (state FIPS 13)...
#   → area within cities = 2,087,067.5 m²
# Processing Treutlen (state FIPS 13)...
#   → area within cities = 70,833.8 m²
# Processing Calhoun (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Vilas (state FIPS 55)...
#   → area within cities = 0.0 m²
# Processing Beltrami (state FIPS 27)...
#   → area within cities = 946,020.8 m²
# Processing Coamo (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Chattooga (state FIPS 13)...
#   → area within cities = 245,507.3 m²
# Processing Dillon (state FIPS 45)...
#   → area within cities = 361,639.5 m²
# Processing Jones (state FIPS 37)...
#   → area within cities = 16,914.9 m²
# Processing Scotland (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Nemaha (state FIPS 20)...
#   → area within cities = 233,999.9 m²
# Processing Norton (state FIPS 20)...
#   → area within cities = 242,078.4 m²
# Processing Aguas Buenas (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Cataño (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Marinette (state FIPS 55)...
#   → area within cities = 836,595.7 m²
# Processing Clark (state FIPS 53)...
#   → area within cities = 12,226,334.0 m²
# Processing Price (state FIPS 55)...
#   → area within cities = 0.0 m²
# Processing Major (state FIPS 40)...
#   → area within cities = 0.0 m²
# Processing Montgomery (state FIPS 47)...
#   → area within cities = 5,565,342.3 m²
# Processing Pend Oreille (state FIPS 53)...
#   → area within cities = 28,514.0 m²
# Processing McLean (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Hood River (state FIPS 41)...
#   → area within cities = 287,945.7 m²
# Processing Wright (state FIPS 19)...
#   → area within cities = 210,337.1 m²
# Processing Shelby (state FIPS 48)...
#   → area within cities = 475,401.4 m²
# Processing Crawford (state FIPS 29)...
#   → area within cities = 699,955.3 m²
# Processing Bath (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Sheridan (state FIPS 56)...
#   → area within cities = 1,224,608.2 m²
# Processing Cumberland (state FIPS 42)...
#   → area within cities = 2,840,057.5 m²
# Processing Franklin (state FIPS 42)...
#   → area within cities = 1,810,398.0 m²
# Processing Luzerne (state FIPS 42)...
#   → area within cities = 5,080,898.0 m²
# Processing Crawford (state FIPS 26)...
#   → area within cities = 23,432.4 m²
# Processing Russell (state FIPS 01)...
#   → area within cities = 1,903,455.0 m²
# Processing Carroll (state FIPS 39)...
#   → area within cities = 406,857.4 m²
# Processing Greene (state FIPS 05)...
#   → area within cities = 682,436.9 m²
# Processing Hall (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Burnett (state FIPS 55)...
#   → area within cities = 0.0 m²
# Processing Torrance (state FIPS 35)...
#   → area within cities = 0.0 m²
# Processing Pacific (state FIPS 53)...
#   → area within cities = 276,968.9 m²
# Processing Pender (state FIPS 37)...
#   → area within cities = 473,423.3 m²
# Processing Hood (state FIPS 48)...
#   → area within cities = 903,516.6 m²
# Processing Washington (state FIPS 31)...
#   → area within cities = 607,991.1 m²
# Processing Clark (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Boone (state FIPS 21)...
#   → area within cities = 2,550,927.7 m²
# Processing Washington (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Avoyelles (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Tate (state FIPS 28)...
#   → area within cities = 219,680.3 m²
# Processing Worth (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Sherman (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Campbell (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Harding (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Gratiot (state FIPS 26)...
#   → area within cities = 422,831.4 m²
# Processing Union (state FIPS 19)...
#   → area within cities = 610,703.9 m²
# Processing Massac (state FIPS 17)...
#   → area within cities = 418,592.3 m²
# Processing Faribault (state FIPS 27)...
#   → area within cities = 361,201.2 m²
# Processing Grainger (state FIPS 47)...
#   → area within cities = 0.0 m²
# Processing Freestone (state FIPS 48)...
#   → area within cities = 340,188.4 m²
# Processing Mifflin (state FIPS 42)...
#   → area within cities = 735,402.9 m²
# Processing Crenshaw (state FIPS 01)...
#   → area within cities = 0.0 m²
# Processing Bristol (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Runnels (state FIPS 48)...
#   → area within cities = 117,878.4 m²
# Processing Terrell (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Rawlins (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Thomas (state FIPS 20)...
#   → area within cities = 192,026.3 m²
# Processing Jeff Davis (state FIPS 13)...
#   → area within cities = 51,181.3 m²
# Processing Cherokee (state FIPS 19)...
#   → area within cities = 490,994.0 m²
# Processing White (state FIPS 05)...
#   → area within cities = 928,977.8 m²
# Processing Leflore (state FIPS 28)...
#   → area within cities = 686,292.2 m²
# Processing Cooper (state FIPS 29)...
#   → area within cities = 754,822.2 m²
# Processing Dickinson (state FIPS 26)...
#   → area within cities = 1,366,739.7 m²
# Processing Will (state FIPS 17)...
#   → area within cities = 25,299,023.9 m²
# Processing Deaf Smith (state FIPS 48)...
#   → area within cities = 731,293.7 m²
# Processing Brookings (state FIPS 46)...
#   → area within cities = 1,776,177.9 m²
# Processing Hardin (state FIPS 19)...
#   → area within cities = 281,691.9 m²
# Processing Cameron (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Clinton (state FIPS 39)...
#   → area within cities = 408,592.5 m²
# Processing St. Louis (state FIPS 27)...
#   → area within cities = 10,135,852.8 m²
# Processing Lorain (state FIPS 39)...
#   → area within cities = 10,262,426.1 m²
# Processing Lewis (state FIPS 47)...
#   → area within cities = 87,542.5 m²
# Processing Washington (state FIPS 41)...
#   → area within cities = 9,176,443.7 m²
# Processing Virginia Beach (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Madison (state FIPS 30)...
#   → area within cities = 0.0 m²
# Processing Lancaster (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Bates (state FIPS 29)...
#   → area within cities = 179,630.5 m²
# Processing Belknap (state FIPS 33)...
#   → area within cities = 625,235.9 m²
# Processing Richmond (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Skagway (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Hoonah-Angoon (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Pettis (state FIPS 29)...
#   → area within cities = 1,398,567.5 m²
# Processing Missoula (state FIPS 30)...
#   → area within cities = 3,311,410.5 m²
# Processing Chautauqua (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Upshur (state FIPS 48)...
#   → area within cities = 222,565.8 m²
# Processing Culpeper (state FIPS 51)...
#   → area within cities = 340,661.5 m²
# Processing Haskell (state FIPS 40)...
#   → area within cities = 47,526.7 m²
# Processing Ohio (state FIPS 54)...
#   → area within cities = 545,780.0 m²
# Processing Morgan (state FIPS 54)...
#   → area within cities = 0.0 m²
# Processing Rockingham (state FIPS 51)...
#   → area within cities = 812,579.8 m²
# Processing Whitley (state FIPS 18)...
#   → area within cities = 322,728.6 m²
# Processing Apache (state FIPS 04)...
#   → area within cities = 306,718.5 m²
# Processing Macon (state FIPS 29)...
#   → area within cities = 326,449.1 m²
# Processing Lamb (state FIPS 48)...
#   → area within cities = 235,673.0 m²
# Processing Kiowa (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Austin (state FIPS 48)...
#   → area within cities = 481,424.8 m²
# Processing Daviess (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Seminole (state FIPS 13)...
#   → area within cities = 58,381.7 m²
# Processing Manistee (state FIPS 26)...
#   → area within cities = 419,687.8 m²
# Processing Lyon (state FIPS 19)...
#   → area within cities = 0.0 m²
# Processing Hutchinson (state FIPS 48)...
#   → area within cities = 922,629.1 m²
# Processing Texas (state FIPS 40)...
#   → area within cities = 406,535.3 m²
# Processing Woodward (state FIPS 40)...
#   → area within cities = 621,192.7 m²
# Processing Adams (state FIPS 19)...
#   → area within cities = 0.0 m²
# Processing St. Croix (state FIPS 55)...
#   → area within cities = 3,947,526.3 m²
# Processing Venango (state FIPS 42)...
#   → area within cities = 2,815,805.5 m²
# Processing Summit (state FIPS 39)...
#   → area within cities = 40,772,710.2 m²
# Processing Glynn (state FIPS 13)...
#   → area within cities = 863,150.3 m²
# Processing Webb (state FIPS 48)...
#   → area within cities = 5,241,342.6 m²
# Processing Montgomery (state FIPS 37)...
#   → area within cities = 213,320.5 m²
# Processing Aroostook (state FIPS 23)...
#   → area within cities = 784,748.0 m²
# Processing Jefferson Davis (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Washington (state FIPS 18)...
#   → area within cities = 121,376.4 m²
# Processing Grant (state FIPS 46)...
#   → area within cities = 235,128.5 m²
# Processing Marshall (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Thurston (state FIPS 53)...
#   → area within cities = 8,373,788.1 m²
# Processing Knox (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Valencia (state FIPS 35)...
#   → area within cities = 7,372,263.4 m²
# Processing Prairie (state FIPS 30)...
#   → area within cities = 0.0 m²
# Processing Piute (state FIPS 49)...
#   → area within cities = 0.0 m²
# Processing Mason (state FIPS 21)...
#   → area within cities = 523,036.7 m²
# Processing Benton (state FIPS 27)...
#   → area within cities = 673,093.8 m²
# Processing Donley (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Bay (state FIPS 12)...
#   → area within cities = 2,764,672.6 m²
# Processing Lauderdale (state FIPS 01)...
#   → area within cities = 3,085,561.2 m²
# Processing Fountain (state FIPS 18)...
# ...
#   → area within cities = 0.0 m²
# Processing Carroll (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Golden Valley (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Niobrara (state FIPS 56)...
#   → area within cities = 0.0 m²
# Processing Pipestone (state FIPS 27)...
#   → area within cities = 172,294.8 m²
# Processing King George (state FIPS 51)...
#   → area within cities = 26,046.9 m²
# Processing Grant (state FIPS 53)...
#   → area within cities = 2,445,670.6 m²
# Processing Renville (state FIPS 27)...
#   → area within cities = 0.0 m²
# Processing Alachua (state FIPS 12)...
#   → area within cities = 10,008,769.6 m²
# Processing Rabun (state FIPS 13)...
#   → area within cities = 22,943.7 m²
# Processing Upshur (state FIPS 54)...
#   → area within cities = 71,109.5 m²
# Processing Texas (state FIPS 29)...
#   → area within cities = 0.0 m²
# Processing Pulaski (state FIPS 05)...
#   → area within cities = 29,615,802.4 m²
# Processing Crawford (state FIPS 19)...
#   → area within cities = 917,319.5 m²
# Processing Bannock (state FIPS 16)...
#   → area within cities = 1,358,703.9 m²
# Processing Geauga (state FIPS 39)...
#   → area within cities = 1,022,213.4 m²
# Processing Cayey (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Tulare (state FIPS 06)...
#   → area within cities = 4,502,861.9 m²
# Processing Arroyo (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing San Germán (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Wayne (state FIPS 36)...
#   → area within cities = 632,717.8 m²
# Processing Rockbridge (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Towner (state FIPS 38)...
#   → area within cities = 0.0 m²
# Processing Delaware (state FIPS 42)...
#   → area within cities = 9,175,028.6 m²
# Processing Niagara (state FIPS 36)...
#   → area within cities = 3,092,831.9 m²
# Processing Marshall (state FIPS 20)...
#   → area within cities = 197,804.6 m²
# Processing Zapata (state FIPS 48)...
#   → area within cities = 878,764.5 m²
# Processing Lee (state FIPS 13)...
#   → area within cities = 367,083.8 m²
# Processing Boyd (state FIPS 21)...
#   → area within cities = 527,939.6 m²
# Processing Carver (state FIPS 27)...
#   → area within cities = 8,348,574.9 m²
# Processing Colfax (state FIPS 31)...
#   → area within cities = 463,069.1 m²
# Processing Chesterfield (state FIPS 45)...
#   → area within cities = 287,772.1 m²
# Processing Jersey (state FIPS 17)...
#   → area within cities = 299,128.3 m²
# Processing Hanover (state FIPS 51)...
#   → area within cities = 99,733.9 m²
# Processing Wallace (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Alger (state FIPS 26)...
#   → area within cities = 34,815.3 m²
# Processing Fulton (state FIPS 05)...
#   → area within cities = 82,143.4 m²
# Processing Hidalgo (state FIPS 48)...
#   → area within cities = 8,483,271.4 m²
# Processing Robeson (state FIPS 37)...
#   → area within cities = 1,689,119.1 m²
# Processing Newaygo (state FIPS 26)...
#   → area within cities = 687,348.3 m²
# Processing Morrow (state FIPS 41)...
#   → area within cities = 181,798.9 m²
# Processing Todd (state FIPS 27)...
#   → area within cities = 195,856.3 m²
# Processing Logan (state FIPS 05)...
#   → area within cities = 252,477.6 m²
# Processing Lincoln (state FIPS 37)...
#   → area within cities = 324,333.4 m²
# Processing Miller (state FIPS 05)...
#   → area within cities = 627,314.7 m²
# Processing Orange (state FIPS 12)...
#   → area within cities = 35,664,487.8 m²
# Processing San Juan (state FIPS 08)...
#   → area within cities = 0.0 m²
# Processing Franklin (state FIPS 16)...
#   → area within cities = 71,902.6 m²
# Processing Carroll (state FIPS 13)...
#   → area within cities = 2,507,813.8 m²
# Processing Riley (state FIPS 20)...
#   → area within cities = 2,718,357.3 m²
# Processing Schleicher (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Russell (state FIPS 51)...
#   → area within cities = 13,109.8 m²
# Processing Caldwell (state FIPS 37)...
#   → area within cities = 1,425,886.4 m²
# Processing Madison (state FIPS 16)...
#   → area within cities = 301,891.9 m²
# Processing Warrick (state FIPS 18)...
#   → area within cities = 465,024.5 m²
# Processing Adair (state FIPS 21)...
#   → area within cities = 15,121.1 m²
# Processing Gallatin (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Harrison (state FIPS 21)...
#   → area within cities = 382,475.6 m²
# Processing Rapides (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Lincoln (state FIPS 31)...
#   → area within cities = 1,747,526.2 m²
# Processing Cass (state FIPS 48)...
#   → area within cities = 664,998.5 m²
# Processing Henry (state FIPS 47)...
#   → area within cities = 337,242.7 m²
# Processing Winchester (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Duplin (state FIPS 37)...
#   → area within cities = 115,716.0 m²
# Processing Haywood (state FIPS 37)...
#   → area within cities = 183,241.9 m²
# Processing Dakota (state FIPS 27)...
#   → area within cities = 40,661,560.9 m²
# Processing Harney (state FIPS 41)...
#   → area within cities = 68,629.2 m²
# Processing Maunabo (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Adams (state FIPS 55)...
#   → area within cities = 0.0 m²
# Processing Mille Lacs (state FIPS 27)...
#   → area within cities = 400,732.0 m²
# Processing Walsh (state FIPS 38)...
#   → area within cities = 183,882.2 m²
# Processing Morgan (state FIPS 39)...
#   → area within cities = 144,155.9 m²
# Processing Portage (state FIPS 39)...
#   → area within cities = 7,434,036.5 m²
# Processing Uinta (state FIPS 56)...
#   → area within cities = 417,014.0 m²
# Processing Humboldt (state FIPS 32)...
#   → area within cities = 158,449.4 m²
# Processing Webster (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Jones (state FIPS 13)...
#   → area within cities = 296,032.6 m²
# Processing Gwinnett (state FIPS 13)...
#   → area within cities = 14,501,340.9 m²
# Processing Polk (state FIPS 55)...
#   → area within cities = 714,516.7 m²
# Processing Green (state FIPS 55)...
#   → area within cities = 529,088.5 m²
# Processing Orocovis (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Putnam (state FIPS 36)...
#   → area within cities = 1,300,867.7 m²
# Processing Newport News (state FIPS 51)...
#   → area within cities = 0.0 m²
# Processing Bent (state FIPS 08)...
#   → area within cities = 43,441.6 m²
# Processing Jackson (state FIPS 40)...
#   → area within cities = 448,419.3 m²
# Processing Sanders (state FIPS 30)...
#   → area within cities = 0.0 m²
# Processing Glasscock (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Franklin (state FIPS 05)...
#   → area within cities = 262,844.2 m²
# Processing Golden Valley (state FIPS 30)...
#   → area within cities = 0.0 m²
# Processing Johnston (state FIPS 37)...
#   → area within cities = 1,226,690.8 m²
# Processing Santa Clara (state FIPS 06)...
#   → area within cities = 78,531,775.9 m²
# Processing Charleston (state FIPS 45)...
#   → area within cities = 17,993,280.7 m²
# Processing Benton (state FIPS 53)...
#   → area within cities = 8,913,721.9 m²
# Processing Adair (state FIPS 29)...
#   → area within cities = 266,809.2 m²
# Processing Erie (state FIPS 39)...
#   → area within cities = 1,000,494.3 m²
# Processing Vermilion (state FIPS 17)...
#   → area within cities = 1,890,526.5 m²
# Processing St. Louis (state FIPS 29)...
#   → area within cities = 45,735,188.2 m²
# Processing Boone (state FIPS 17)...
#   → area within cities = 2,381,848.3 m²
# Processing Tehama (state FIPS 06)...
#   → area within cities = 535,675.4 m²
# Processing Dane (state FIPS 55)...
#   → area within cities = 37,387,241.6 m²
# Processing Fisher (state FIPS 48)...
#   → area within cities = 0.0 m²
# Processing Sabine (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Morgan (state FIPS 17)...
#   → area within cities = 797,030.4 m²
# Processing Morehouse (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Bullitt (state FIPS 21)...
#   → area within cities = 163,967.7 m²
# Processing Dallas (state FIPS 01)...
#   → area within cities = 1,125,363.1 m²
# Processing Comanche (state FIPS 48)...
#   → area within cities = 136,729.9 m²
# Processing Lincoln (state FIPS 30)...
#   → area within cities = 330,737.2 m²
# Processing San Lorenzo (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Toa Alta (state FIPS 72)...
#   → area within cities = 0.0 m²
# Processing Cass (state FIPS 27)...
#   → area within cities = 0.0 m²
# Processing Archuleta (state FIPS 08)...
#   → area within cities = 117,502.5 m²
# Processing Lincoln (state FIPS 16)...
#   → area within cities = 0.0 m²
# Processing Lancaster (state FIPS 42)...
#   → area within cities = 7,456,244.4 m²
# Processing Juneau (state FIPS 55)...
#   → area within cities = 176,513.4 m²
# Processing Fairbanks North Star (state FIPS 02)...
#   → area within cities = 0.0 m²
# Processing Henderson (state FIPS 21)...
#   → area within cities = 1,051,815.7 m²
# Processing Okeechobee (state FIPS 12)...
#   → area within cities = 85,260.6 m²
# Processing Union (state FIPS 13)...
#   → area within cities = 0.0 m²
# Processing Black Hawk (state FIPS 19)...
#   → area within cities = 7,386,128.1 m²
# Processing Sabine (state FIPS 48)...
#   → area within cities = 123,339.2 m²
# Processing Pike (state FIPS 39)...
#   → area within cities = 264,568.7 m²
# Processing Tuscaloosa (state FIPS 01)...
#   → area within cities = 3,274,164.3 m²
# Processing Wilcox (state FIPS 01)...
#   → area within cities = 0.0 m²
# Processing Montgomery (state FIPS 28)...
#   → area within cities = 80,963.5 m²
# Processing Kearney (state FIPS 31)...
#   → area within cities = 83,760.2 m²
# Processing Hitchcock (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing New Castle (state FIPS 10)...
#   → area within cities = 6,287,513.9 m²
# Processing Teton (state FIPS 16)...
#   → area within cities = 0.0 m²
# Processing Rock Island (state FIPS 17)...
#   → area within cities = 6,881,845.7 m²
# Processing Gloucester (state FIPS 51)...
#   → area within cities = 131,566.8 m²
# Processing Sevier (state FIPS 05)...
#   → area within cities = 183,826.2 m²
# Processing Cass (state FIPS 18)...
#   → area within cities = 540,597.7 m²
# Processing Power (state FIPS 16)...
#   → area within cities = 180,163.3 m²
# Processing Carroll (state FIPS 18)...
#   → area within cities = 130,887.6 m²
# Processing Philadelphia (state FIPS 42)...
#   → area within cities = 41,310,499.0 m²
# Processing Washakie (state FIPS 56)...
#   → area within cities = 360,414.7 m²
# Processing Camden (state FIPS 37)...
#   → area within cities = 0.0 m²
# Processing Tompkins (state FIPS 36)...
#   → area within cities = 1,713,699.9 m²
# Processing Jefferson (state FIPS 05)...
#   → area within cities = 2,798,427.5 m²
# Processing Lincoln (state FIPS 05)...
#   → area within cities = 0.0 m²
# Processing Madison (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Valley (state FIPS 30)...
#   → area within cities = 63,177.8 m²
# Processing Whitfield (state FIPS 13)...
#   → area within cities = 2,265,928.5 m²
# Processing Wichita (state FIPS 20)...
#   → area within cities = 0.0 m²
# Processing Charles Mix (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Cedar (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Kitsap (state FIPS 53)...
#   → area within cities = 11,032,678.1 m²
# Processing McHenry (state FIPS 17)...
#   → area within cities = 18,756,695.6 m²
# Processing Petroleum (state FIPS 30)...
#   → area within cities = 0.0 m²
# Processing Carroll (state FIPS 29)...
#   → area within cities = 154,137.2 m²
# Processing Whitman (state FIPS 53)...
#   → area within cities = 1,381,750.9 m²
# Processing Steele (state FIPS 27)...
#   → area within cities = 1,265,031.6 m²
# Processing Kenton (state FIPS 21)...
#   → area within cities = 6,278,478.4 m²
# Processing Chickasaw (state FIPS 19)...
#   → area within cities = 137,721.1 m²
# Processing DeKalb (state FIPS 17)...
#   → area within cities = 2,996,432.8 m²
# Processing Hancock (state FIPS 19)...
#   → area within cities = 37,499.7 m²
# Processing Stark (state FIPS 38)...
#   → area within cities = 614,647.2 m²
# Processing Luce (state FIPS 26)...
#   → area within cities = 32,067.5 m²
# Processing Carter (state FIPS 40)...
#   → area within cities = 425,789.5 m²
# Processing Pasquotank (state FIPS 37)...
#   → area within cities = 325,852.3 m²
# Processing Taos (state FIPS 35)...
#   → area within cities = 167,333.5 m²
# Processing Bolivar (state FIPS 28)...
#   → area within cities = 490,528.6 m²
# Processing Nye (state FIPS 32)...
#   → area within cities = 274,302.6 m²
# Processing Fleming (state FIPS 21)...
#   → area within cities = 22,469.4 m²
# Processing Clark (state FIPS 55)...
#   → area within cities = 94,621.9 m²
# Processing York (state FIPS 45)...
#   → area within cities = 2,849,506.9 m²
# Processing Adams (state FIPS 18)...
#   → area within cities = 428,688.8 m²
# Processing Ascension (state FIPS 22)...
#   → area within cities = 0.0 m²
# Processing Webster (state FIPS 28)...
#   → area within cities = 0.0 m²
# Processing Franklin (state FIPS 25)...
#   → area within cities = 1,570,817.6 m²
# Processing Cherry (state FIPS 31)...
#   → area within cities = 134,381.8 m²
# Processing Beaverhead (state FIPS 30)...
#   → area within cities = 141,760.1 m²
# Processing New Madrid (state FIPS 29)...
#   → area within cities = 261,839.1 m²
# Processing Hempstead (state FIPS 05)...
#   → area within cities = 576,745.1 m²
# Processing Camden (state FIPS 29)...
#   → area within cities = 166,646.8 m²
# Processing Campbell (state FIPS 51)...
#   → area within cities = 1,054,689.0 m²
# Processing Meigs (state FIPS 39)...
#   → area within cities = 90,957.2 m²
# Processing Nicholas (state FIPS 54)...
#   → area within cities = 203,612.3 m²
# Processing Grant (state FIPS 40)...
#   → area within cities = 0.0 m²
# Processing Spink (state FIPS 46)...
#   → area within cities = 0.0 m²
# Processing Windsor (state FIPS 50)...
#   → area within cities = 610,935.2 m²
# Processing Trinity (state FIPS 48)...
#   → area within cities = 59,609.4 m²
# Processing Bernalillo (state FIPS 35)...
#   → area within cities = 56,494,061.7 m²
# Processing Mitchell (state FIPS 13)...
#   → area within cities = 253,485.0 m²
# Processing Hawaii (state FIPS 15)...
#   → area within cities = 1,294,052.1 m²
# Processing McCreary (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Pendleton (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Spencer (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Hill (state FIPS 30)...
#   → area within cities = 296,267.5 m²
# Processing Valley (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Castro (state FIPS 48)...
#   → area within cities = 161,258.4 m²
# Processing Washington (state FIPS 24)...
#   → area within cities = 2,449,477.5 m²
# Processing Letcher (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Salem (state FIPS 34)...
#   → area within cities = 352,744.8 m²
# Processing Maury (state FIPS 47)...
#   → area within cities = 2,013,823.3 m²
# Processing Goshen (state FIPS 56)...
#   → area within cities = 198,570.0 m²
# Processing Rusk (state FIPS 55)...
#   → area within cities = 376,641.2 m²
# Processing Waukesha (state FIPS 55)...
#   → area within cities = 25,137,235.3 m²
# Processing Garrard (state FIPS 21)...
#   → area within cities = 0.0 m²
# Processing Clallam (state FIPS 53)...
#   → area within cities = 1,213,264.0 m²
# Processing Stevens (state FIPS 53)...
#   → area within cities = 423,670.4 m²
# Processing Van Buren (state FIPS 19)...
#   → area within cities = 0.0 m²
# Processing Gosper (state FIPS 31)...
#   → area within cities = 0.0 m²
# Processing Monroe (state FIPS 28)...
#   → area within cities = 382,985.8 m²
# Processing Escambia (state FIPS 12)...
#   → area within cities = 3,774,319.5 m²
#
# Top 5 counties by park area within cities:
#            county state_fips county_fips  geoid  area_m2_citybounded  \
# 1918     Maricopa         04         013  04013         3.087466e+08
# 1993  Los Angeles         06         037  06037         2.504030e+08
# 1896    San Diego         06         073  06073         1.851398e+08
# 1574       Harris         48         201  48201         1.832321e+08
# 2298       Dallas         48         113  48113         1.534253e+08
#
#             date
# 1918  2025-10-29
# 1993  2025-10-29
# 1896  2025-10-29
# 1574  2025-10-29
# 2298  2025-10-29

# %%
print(f"total area: {bounded_area_df['area_m2_citybounded'].sum()}")
# Out:
# total area: 9208931150.99102

# %%
import requests
import geopandas as gpd
from shapely.geometry import shape
import pandas as pd
from datetime import datetime

# --- Config ---
equal_area_crs = "EPSG:5070"  # Equal-area CRS for area calculations
today = datetime.today().strftime("%Y-%m-%d")

# Census TIGER base URLs (official)
COUNTY_URL = "https://www2.census.gov/geo/tiger/TIGER2025/COUNTY/tl_2025_us_county.zip"
PLACE_BASE_URL = "https://www2.census.gov/geo/tiger/TIGER2025/PLACE/tl_2025_{statefp}_place.zip"

# ParkServe endpoint
PARKSERVE_URL = "https://server7.tplgis.org/arcgis7/rest/services/ParkServe/ParkServe_ProdNew/MapServer/2/query"
PARKSERVE_CONDITION = "(park_designation = 'LP' OR park_designation = 'LREC')"

# --- Load all counties (nationwide shapefile) ---
print("Loading counties...")
counties_gdf = gpd.read_file(COUNTY_URL).to_crs("EPSG:4326")

# Create readable columns
counties_gdf["statefp"] = counties_gdf["STATEFP"]
counties_gdf["countyfp"] = counties_gdf["COUNTYFP"]
counties_gdf["geoid"] = counties_gdf["GEOID"]
counties_gdf["county_name"] = counties_gdf["NAME"]
counties_gdf["name_full"] = (
    counties_gdf["county_name"] + ", " + counties_gdf["STATEFP"].map(str)
)
counties_gdf = counties_gdf.to_crs(equal_area_crs)

# --- Load all cities ("places") ---
print("Loading city shapefiles by state...")
state_fips_list = counties_gdf["statefp"].unique().tolist()

city_gdfs = []
for fips in state_fips_list:
    url = PLACE_BASE_URL.format(statefp=fips.zfill(2))
    try:
        gdf = gpd.read_file(url)
        gdf["statefp"] = fips
        gdf = gdf.to_crs(equal_area_crs)
        city_gdfs.append(gdf)
    except Exception as e:
        print(f"  ⚠️ Failed to load {url}: {e}")

cities_gdf = pd.concat(city_gdfs, ignore_index=True)
print(f"Loaded {len(cities_gdf)} city polygons across {len(state_fips_list)} states.")

# --- ParkServe helper function ---
def fetch_features_for_county(county_name, state_fips):
    """Fetch ParkServe parks by county and state FIPS"""
    features = []
    offset = 0
    while True:
        where_clause = (
            f"Park_State_FIPS = '{state_fips}' AND Park_County = '{county_name} County'"
        )
        params = {
            "where": where_clause,
            "outFields": "*",
            "f": "geojson",
            "resultOffset": offset,
            "resultRecordCount": 1000,
        }
        r = requests.get(PARKSERVE_URL, params=params, timeout=60)
        r.raise_for_status()
        gj = r.json()
        page_features = gj.get("features", [])
        if not page_features:
            break
        features.extend(page_features)
        if len(page_features) < 1000:
            break
        offset += 1000
    return features


def parks_within_cities(features_geojson, city_gdf):
    """Intersect ParkServe features with city boundaries and sum area within them."""
    if not features_geojson:
        return 0.0

    parks = gpd.GeoDataFrame(
        geometry=[shape(f["geometry"]) for f in features_geojson if f.get("geometry")],
        crs="EPSG:4326",
    ).to_crs(equal_area_crs)

    # Fix invalid geometries
    parks["geometry"] = parks.buffer(0)
    parks = parks[~parks.geometry.is_empty]

    # Intersect with cities (same CRS)
    parks_in_cities = gpd.overlay(parks, city_gdf, how="intersection")

    if parks_in_cities.empty:
        return 0.0

    # Compute total area (in m²)
    return float(parks_in_cities.geometry.area.sum())


# --- Main loop ---
rows_all = []
for _, row in counties_gdf.iterrows():
    county_name = row["county_name"]
    state_fips = row["statefp"]
    geoid = row["geoid"]

    try:
        features = fetch_features_for_county(county_name, state_fips)

        # Get all cities within this county geometry
        county_geom = row["geometry"]
        cities_in_county = cities_gdf[cities_gdf.intersects(county_geom)]

        area_m2 = parks_within_cities(features, cities_in_county)
        rows_all.append(
            {
                "county": county_name,
                "state_fips": state_fips,
                "county_fips": row["countyfp"],
                "geoid": geoid,
                "area_m2_citybounded": area_m2,
                "date": today,
            }
        )

    except Exception as e:
        print(f"  ❌ ERROR processing {county_name}: {e}")
        rows_all.append(
            {
                "county": county_name,
                "state_fips": state_fips,
                "county_fips": row["countyfp"],
                "geoid": geoid,
                "area_m2_citybounded": float("nan"),
                "date": today,
            }
        )

# --- Results ---
bounded_area_df_all = pd.DataFrame(rows).sort_values("area_m2_citybounded", ascending=False)
print("\nTop 5 counties by park area within cities:")
print(bounded_area_df.head())
# Out:
# Loading counties...
# Loading city shapefiles by state...
# Loaded 32629 city polygons across 56 states.
#
# Top 5 counties by park area within cities:
#            county state_fips county_fips  geoid  area_m2_citybounded  \
# 1918     Maricopa         04         013  04013         3.087466e+08
# 1993  Los Angeles         06         037  06037         2.504030e+08
# 1896    San Diego         06         073  06073         1.851398e+08
# 1574       Harris         48         201  48201         1.832321e+08
# 2298       Dallas         48         113  48113         1.534253e+08
#
#             date
# 1918  2025-10-29
# 1993  2025-10-29
# 1896  2025-10-29
# 1574  2025-10-29
# 2298  2025-10-29

# %%
print(f"total area: {bounded_area_df_all['area_m2_citybounded'].sum()}")
# Out:
# total area: 9208931150.99102

# %%
import requests
import geopandas as gpd
from shapely.geometry import shape
import pandas as pd
from datetime import datetime

# --- Config ---
equal_area_crs = "EPSG:5070"  # Equal-area CRS for accurate area
today = datetime.today().strftime("%Y-%m-%d")

# --- TIGER/Line Sources ---
COUNTY_URL = "https://www2.census.gov/geo/tiger/TIGER2025/COUNTY/tl_2025_us_county.zip"
PLACE_BASE_URL = "https://www2.census.gov/geo/tiger/TIGER2025/PLACE/tl_2025_{statefp}_place.zip"

# --- ParkServe Endpoint ---
PARKSERVE_URL = "https://server7.tplgis.org/arcgis7/rest/services/ParkServe/ParkServe_ProdNew/MapServer/2/query"
PARKSERVE_CONDITION = "(park_designation = 'LP' OR park_designation = 'LREC')"

# --- Load all counties ---
print("Loading counties...")
counties_gdf = gpd.read_file(COUNTY_URL).to_crs("EPSG:4326")
counties_gdf["statefp"] = counties_gdf["STATEFP"]
counties_gdf["countyfp"] = counties_gdf["COUNTYFP"]
counties_gdf["geoid"] = counties_gdf["GEOID"]
counties_gdf["county_name"] = counties_gdf["NAME"]
counties_gdf = counties_gdf.to_crs(equal_area_crs)

# --- Load all cities (places) ---
print("Loading city shapefiles by state...")
state_fips_list = counties_gdf["statefp"].unique().tolist()  # ✅ Only valid states
city_gdfs = []

for fips in state_fips_list:
    url = PLACE_BASE_URL.format(statefp=fips.zfill(2))
    try:
        gdf = gpd.read_file(url)
        gdf["statefp"] = fips
        gdf = gdf.to_crs(equal_area_crs)
        city_gdfs.append(gdf)
    except Exception as e:
        print(f"  ⚠️ Failed to load {url}: {e}")

cities_gdf = pd.concat(city_gdfs, ignore_index=True)
print(f"✅ Loaded {len(cities_gdf)} city polygons across {len(state_fips_list)} states.")

# --- ParkServe Fetch Helper ---
def fetch_features_for_state(state_fips):
    """Fetch ParkServe features by state FIPS (entire state)."""
    features = []
    offset = 0
    while True:
        params = {
            "where": f"Park_State_FIPS = '{state_fips}' AND {PARKSERVE_CONDITION}",
            "outFields": "*",
            "f": "geojson",
            "resultOffset": offset,
            "resultRecordCount": 1000,
        }
        r = requests.get(PARKSERVE_URL, params=params, timeout=60)
        r.raise_for_status()
        gj = r.json()
        page = gj.get("features", [])
        if not page:
            break
        features.extend(page)
        if len(page) < 1000:
            break
        offset += 1000
    return features

def park_area_within_city(parks_gdf, city_geom):
    """Compute total park area within a single city geometry."""
    parks_in_city = gpd.overlay(parks_gdf, gpd.GeoDataFrame(geometry=[city_geom], crs=equal_area_crs), how="intersection")
    return float(parks_in_city.geometry.area.sum()) if not parks_in_city.empty else 0.0

# --- Main Loop ---
rows_all = []

for state_fips in state_fips_list:
    print(f"Processing state {state_fips}...")
    try:
        features = fetch_features_for_state(state_fips)
        if not features:
            print(f"  ⚠️ No parks found for state {state_fips}.")
            continue

        # Convert parks to GeoDataFrame (equal-area CRS)
        parks = gpd.GeoDataFrame(
            geometry=[shape(f["geometry"]) for f in features if f.get("geometry")],
            crs="EPSG:4326",
        ).to_crs(equal_area_crs)

        # Fix invalid geometries
        parks["geometry"] = parks.buffer(0)
        parks = parks[~parks.geometry.is_empty]

        # Cities for this state
        cities_state = cities_gdf[cities_gdf["statefp"] == state_fips]

        for _, city in cities_state.iterrows():
            area_m2 = park_area_within_city(parks, city.geometry)
            rows_all.append(
                {
                    "state_fips": state_fips,
                    "placefp": city["PLACEFP"],
                    "city_name": city["NAME"],
                    "area_m2_parks": area_m2,
                    "date": today,
                }
            )

    except Exception as e:
        print(f"  ❌ ERROR processing state {state_fips}: {e}")

# --- Results ---
bounded_area_df = pd.DataFrame(rows_all).sort_values("area_m2_parks", ascending=False)
print(f"\n✅ Completed. {len(bounded_area_df)} cities processed.")
print("\nTop 5 cities by total park area:")
print(bounded_area_df.head())

# (optional) save to file
bounded_area_df.to_csv(f"parkserve_city_areas_{today}.csv", index=False)
# Out:
# Loading counties...
# Loading city shapefiles by state...
# ✅ Loaded 32629 city polygons across 56 states.
# Processing state 40...
# Processing state 46...
# Processing state 37...
# Processing state 48...
# Processing state 39...
# Processing state 72...
# Processing state 35...
# Processing state 20...
# Processing state 13...
# Processing state 55...
# Processing state 01...
# Processing state 47...
# Processing state 51...
# Processing state 05...
# Processing state 22...
# Processing state 12...
# Processing state 21...
# Processing state 32...
# Processing state 06...
# Processing state 28...
# Processing state 31...
# Processing state 27...
# Processing state 19...
# Processing state 33...
# Processing state 08...
# Processing state 36...
# Processing state 53...
# Processing state 41...
# Processing state 29...
# Processing state 18...
# Processing state 38...
# Processing state 30...
# Processing state 26...
# Processing state 44...
# Processing state 17...
# Processing state 04...
# Processing state 02...
# Processing state 54...
# Processing state 45...
# Processing state 23...
# Processing state 42...
# Processing state 16...
# Processing state 49...
# Processing state 34...
# Processing state 50...
# Processing state 10...
# Processing state 78...
#   ⚠️ No parks found for state 78.
# Processing state 56...
# Processing state 24...
# Processing state 25...
# Processing state 60...
#   ⚠️ No parks found for state 60.
# Processing state 66...
#   ⚠️ No parks found for state 66.
# Processing state 69...
#   ⚠️ No parks found for state 69.
# Processing state 15...
# Processing state 09...
# Processing state 11...
#
# ✅ Completed. 32350 cities processed.
#
# Top 5 cities by total park area:
#       state_fips placefp                                          city_name  \
# 25633         04   55000                                            Phoenix
# 2555          48   35000                                            Houston
# 9140          47   52006  Nashville-Davidson metropolitan government (ba...
# 13158         06   66000                                          San Diego
# 12942         06   44000                                        Los Angeles
#
#        area_m2_parks        date
# 25633   1.670919e+08  2025-10-30
# 2555    1.662058e+08  2025-10-30
# 9140    1.142194e+08  2025-10-30
# 13158   1.062226e+08  2025-10-30
# 12942   9.020624e+07  2025-10-30

# %%
bounded_area_df.area_m2_parks.sum()
# Out:
# 9655146991.715569

# %%
bounded_area_df.head()
# Out:
#       state_fips placefp                                          city_name  \
# 25633         04   55000                                            Phoenix
# 2555          48   35000                                            Houston
# 9140          47   52006  Nashville-Davidson metropolitan government (ba...
# 13158         06   66000                                          San Diego
# 12942         06   44000                                        Los Angeles
#
#        area_m2_parks        date
# 25633   1.670919e+08  2025-10-30
# 2555    1.662058e+08  2025-10-30
# 9140    1.142194e+08  2025-10-30
# 13158   1.062226e+08  2025-10-30
# 12942   9.020624e+07  2025-10-30

# %%
pop_file = pd.read_csv("data/sub-est2024.csv", sep=",", encoding="latin1")

# %%
import pandas as pd

# Load both datasets
parks_df = bounded_area_df
pop_df = pd.read_csv("data/sub-est2024.csv", encoding="latin1")

# Keep only "place" rows (SUMLEV 162 = incorporated places, 157 = county subdivisions)
pop_places = pop_df[pop_df["SUMLEV"].isin([157, 162])].copy()

# Zero-pad state and place codes
pop_places["STATEFP"] = pop_places["STATE"].astype(str).str.zfill(2)
pop_places["PLACEFP"] = pop_places["PLACE"].astype(str).str.zfill(5)

parks_df["statefp"] = parks_df["state_fips"].astype(str).str.zfill(2)
parks_df["placefp"] = parks_df["placefp"].astype(str).str.zfill(5)

# Create a join key
pop_places["place_id"] = pop_places["STATEFP"] + pop_places["PLACEFP"]
parks_df["place_id"] = parks_df["statefp"] + parks_df["placefp"]

# Merge population into parks data
merged = parks_df.merge(
    pop_places[["place_id", "NAME", "POPESTIMATE2024"]],
    on="place_id",
    how="left"
)

# Rename for clarity
merged = merged.rename(columns={
    "NAME": "place_name",
    "POPESTIMATE2024": "population_2024"
})

print(merged.head())
# Out:
#   state_fips placefp city_name  area_m2_parks        date statefp place_id  \
# 0         04   55000   Phoenix   1.670919e+08  2025-10-30      04  0455000
# 1         04   55000   Phoenix   1.670919e+08  2025-10-30      04  0455000
# 2         48   35000   Houston   1.662058e+08  2025-10-30      48  4835000
# 3         48   35000   Houston   1.662058e+08  2025-10-30      48  4835000
# 4         48   35000   Houston   1.662058e+08  2025-10-30      48  4835000
#
#            place_name  population_2024
# 0        Phoenix city        1673164.0
# 1        Phoenix city        1673164.0
# 2        Houston city        2390125.0
# 3  Houston city (pt.)          43887.0
# 4  Houston city (pt.)        2339948.0

# %%
high_population_places = merged[merged.population_2024 > 250000]
medium_population_places = merged[(merged["population_2024"] > 100000) & (merged["population_2024"] < 250000)]
low_population_places = merged[merged.population_2024 < 100000]

# %%
high_population_places.describe()
# Out:
#        area_m2_parks  population_2024
# count   1.900000e+02     1.900000e+02
# mean    2.933799e+07     6.705999e+05
# std     3.150416e+07     8.144857e+05
# min     1.493510e+06     2.502660e+05
# 25%     1.088941e+07     3.039632e+05
# 50%     1.903634e+07     4.230235e+05
# 75%     3.436704e+07     6.810228e+05
# max     1.670919e+08     8.478072e+06

# %%
medium_population_places.describe()
# Out:
#        area_m2_parks  population_2024
# count   4.920000e+02       492.000000
# mean    5.762534e+06    144295.067073
# std     7.126514e+06     38967.789121
# min     9.894575e+04    100128.000000
# 25%     1.953298e+06    112422.000000
# 50%     3.735783e+06    134342.000000
# 75%     6.923462e+06    168477.750000
# max     6.440828e+07    246170.000000

# %%
low_population_places.describe()
# Out:
#        area_m2_parks  population_2024
# count   3.951800e+04     39518.000000
# mean    3.018703e+05      5827.820942
# std     2.305015e+06     12977.704873
# min     0.000000e+00         0.000000
# 25%     0.000000e+00       315.000000
# 50%     0.000000e+00      1037.000000
# 75%     1.271156e+05      4432.000000
# max     1.662058e+08     99999.000000

# %%
import pandas as pd
city_parks = pd.read_csv('output/city_parks_contiguous_2025-11-02.csv')

# %%
city_parks
# Out:
#        statefp  placefp           city_name  osm_area_m2  parkserve_area_m2  \
# 0            1    17176             Coosada          0.0                0.0
# 1            1     9736           Brookside          0.0                0.0
# 2            1    64152            Rehobeth          0.0                0.0
# 3            1    81720            Wetumpka          0.0                0.0
# 4            1      460          Adamsville          0.0                0.0
# ...        ...      ...                 ...          ...                ...
# 31535       56    55200       Mountain View          0.0                0.0
# 31536       56    81640          Warren AFB          0.0                0.0
# 31537       56    86737           Y-O Ranch          0.0                0.0
# 31538       56    75355          Table Rock          0.0                0.0
# 31539       56    84852  Woods Landing-Jelm          0.0                0.0
#
#        combined_area_m2  overlap_area_m2        date
# 0                   0.0              0.0  2025-11-02
# 1                   0.0              0.0  2025-11-02
# 2                   0.0              0.0  2025-11-02
# 3                   0.0              0.0  2025-11-02
# 4                   0.0              0.0  2025-11-02
# ...                 ...              ...         ...
# 31535               0.0              0.0  2025-11-02
# 31536               0.0              0.0  2025-11-02
# 31537               0.0              0.0  2025-11-02
# 31538               0.0              0.0  2025-11-02
# 31539               0.0              0.0  2025-11-02
#
# [31540 rows x 8 columns]

# %%
city_parks.osm_area_m2.sum()
# Out:
# 0.0
