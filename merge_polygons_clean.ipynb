# %%
import geopandas as gpd
import pandas as pd
from shapely.ops import unary_union
import os
import math

# %%
# This notebook takes in multiple files in gpkg format, and merges them up to 20 million square feet. 
# Once that limit is reached, it will begin the process again, until running out of polygons to merge.

# %%
# Create a gdf dictionary where {key = name representation: value = gdf file}
def create_gdf_dict(filename_list):
    gdf_dict = {}
    
    # Get the name mapped to each gdf in dictionary form
    for file_str in filename_list:
        current_gpd = gpd.read_file(file_str)
        base_name = os.path.splitext(file_str)[0]
        
        gdf_dict[base_name] = current_gpd

    return gdf_dict

# Turn the final list into a dictionary for easy access and name representation
def turn_list_to_dict(merged_list):
    list_to_dict = {}
    name = "file"
    count = 1
    
    for gdf in merged_list:
        list_to_dict[name + str(count)] = gdf
        count += 1

    return list_to_dict

# Generates the utm value for the given shape file
def auto_utm(gdf):
    gdf = gdf.to_crs("EPSG:4326")
    
    # Get centroid coordinates (in lon/lat)
    cent = gdf.to_crs(3857).centroid.to_crs(gdf.crs)
    lon = cent.x.mean()
    lat = cent.y.mean()

    # Compute UTM zone
    zone = int((lon + 180) / 6) + 1
    if lat >= 0:
        epsg = 32600 + zone  # Northern Hemisphere
    else:
        epsg = 32700 + zone  # Southern Hemisphere

    return epsg

# retrieve the total area (in meters) of a multipolygon shape file
def check_total_area(gpkg_file):
    epsg = auto_utm(gpkg_file)
    
    gdf = gpkg_file.to_crs(epsg=epsg)
    gdf["area"] = gdf.geometry.area
    gdf = gdf.sort_values("area", ascending=False)
    total_area = 0

    for idx, row in gdf.iterrows():
        total_area += row["area"]

    print(gdf.crs)

    return total_area

# %%
gdf= gpd.read_file("unified_geopackages_just_unified/state_17_unified.gpkg")
gdf = gdf.set_crs(4326, allow_override=True)
result = gdf[["city_name", "geometry"]].copy()

# %%
import geopandas as gpd
import pandas as pd
from shapely.ops import unary_union

gpkg = "unified_geopackages_updated/state_54_unified.gpkg"

# -----------------------------
# Load layers with forced CRS
# -----------------------------
def load_layer(name):
    gdf = gpd.read_file(gpkg, layer=name)
    gdf = gdf.set_crs(4326, allow_override=True)
    return gdf[["city_name", "geometry"]]

gdf_indoor = load_layer("indoor_gyms")
gdf_parkserve = load_layer("parkserve_geom")
gdf_osm = load_layer("osm_geom")

# -----------------------------
# Merge all 3 layers on city_name
# Outer join keeps all cities from any layer
# -----------------------------
merged = (
    gdf_indoor.rename(columns={"geometry": "geom_indoor"})
    .merge(gdf_parkserve.rename(columns={"geometry": "geom_parkserve"}), on="city_name", how="outer")
    .merge(gdf_osm.rename(columns={"geometry": "geom_osm"}), on="city_name", how="outer")
)

for col in ["geom_indoor", "geom_parkserve", "geom_osm"]:
    merged[col] = merged[col].apply(lambda g: make_valid(g) if g is not None else None)
# -----------------------------
# Union geometries city-by-city
# -----------------------------
union_geoms = []

for idx, row in merged.iterrows():
    geoms = []

    for col in ["geom_indoor", "geom_parkserve", "geom_osm"]:
        geom = row[col]
        if geom is not None and not geom.is_empty:
            geoms.append(geom)

    if len(geoms) == 0:
        union_geoms.append(None)
    else:
        union_geoms.append(unary_union(geoms))

merged["geometry"] = union_geoms

# -----------------------------
# Final output
# -----------------------------
result = merged[["city_name", "geometry"]].copy()
result = gpd.GeoDataFrame(result, geometry="geometry", crs="EPSG:4326")

print(result)
# Out:
#                      city_name  \
# 0    Addison (Webster Springs)
# 1                     Albright
# 2                     Alderson
# 3                   Alum Creek
# 4                       Ansted
# ..                         ...
# 262                 Williamson
# 263               Williamstown
# 264            Windsor Heights
# 265                   Winfield
# 266                Worthington
#
#                                               geometry
# 0    MULTIPOLYGON (((-80.411 38.475, -80.411 38.474...
# 1    POLYGON ((-79.644 39.494, -79.643 39.494, -79....
# 2    MULTIPOLYGON (((-80.637 37.724, -80.637 37.724...
# 3    MULTIPOLYGON (((-81.835 38.263, -81.835 38.263...
# 4    MULTIPOLYGON (((-81.113 38.122, -81.113 38.122...
# ..                                                 ...
# 262  MULTIPOLYGON (((-82.266 37.664, -82.266 37.664...
# 263  MULTIPOLYGON (((-81.448 39.394, -81.45 39.394,...
# 264  MULTIPOLYGON (((-80.664 40.192, -80.664 40.192...
# 265  MULTIPOLYGON (((-81.893 38.531, -81.893 38.531...
# 266  POLYGON ((-80.267 39.45, -80.267 39.45, -80.26...
#
# [267 rows x 2 columns]

# %%
import pandas as pd
import math

MAX_AREA_FT2 = 700_000

def split_gpkg_greedy_by_city(
    gdf,
    MAX_ft2=19_970_000
):
    # Remove invalid geometries
    gdf = gdf[~gdf.geometry.is_empty & gdf.geometry.notnull()].copy()

    # Safe CRS → UTM
    target_crs = auto_utm(gdf)
    gdf = gdf.to_crs(target_crs)

    #Explode each city polygon and filter
    gdf = gdf.explode(index_parts=False).reset_index(drop=True)
    gdf["area_ft2"] = gdf.geometry.area * 10.76391

    gdf = gdf[gdf["area_ft2"] <= MAX_AREA_FT2]

    # Group by city where possible
    city_col = "city_name"
    city_groups = {city: group for city, group in gdf.groupby(city_col)}
    city_areas = {city: group["area_ft2"].sum() for city, group in city_groups.items()} 

    # Safe centroids
    city_centroids = {}
    for city, group in city_groups.items():
        try:
            centroid = group.geometry.union_all().centroid
        except Exception:
            centroid = group.geometry.centroid.iloc[0]
        city_centroids[city] = centroid

    merged_file_list = []
    gdf_accum = None
    total_area = 0
    remaining_cities = list(city_groups.keys())
    last_centroid = None

    last_chunks = []  # <-- store last chunks of oversized cities

    while remaining_cities:

        # Pick next city
        if last_centroid is None:
            candidates = sorted(
                remaining_cities,
                key=lambda c: (city_centroids[c].y, city_centroids[c].x)
            )
            next_city = candidates[0]
        else:
            candidates = [
                c for c in remaining_cities
                if total_area + city_areas[c] <= MAX_ft2
            ]
            if not candidates:
                candidates = remaining_cities
            next_city = min(
                candidates,
                key=lambda c: city_centroids[c].distance(last_centroid)
            )

        current_gdf = city_groups.pop(next_city)
        current_area = city_areas.pop(next_city)
        last_centroid = city_centroids.pop(next_city)
        remaining_cities.remove(next_city)

        # Oversized city handling
        if current_area > MAX_ft2:
            #To maximize area per file, we group the large files first and then fill the gaps with the smaller parks
            exploded_sorted = current_gdf.sort_values("area_ft2", ascending=False)

            chunk_accum = []
            chunk_total = 0
            chunk_idx = 1

            for _, row in exploded_sorted.iterrows():
                row_gdf = gpd.GeoDataFrame(row.to_frame().T, geometry='geometry', crs=current_gdf.crs)

                if chunk_total + row["area_ft2"] > MAX_ft2:
                    if chunk_accum:
                        chunk_gdf = gpd.GeoDataFrame(pd.concat(chunk_accum, ignore_index=True),
                                                     geometry='geometry', crs=current_gdf.crs)
                        chunk_gdf["city_name"] = f"{next_city}_{chunk_idx}"
                        merged_file_list.append(chunk_gdf)
                        chunk_idx += 1
                    chunk_accum = [row_gdf]
                    chunk_total = row["area_ft2"]
                else:
                    chunk_accum.append(row_gdf)
                    chunk_total += row["area_ft2"]

            # === Keep last chunk separate ===
            if chunk_accum:
                last_chunk_gdf = gpd.GeoDataFrame(pd.concat(chunk_accum, ignore_index=True),
                                                  geometry='geometry', crs=current_gdf.crs)
                last_chunk_gdf["city_name"] = f"{next_city}_{chunk_idx}"
                last_chunks.append(last_chunk_gdf)  # store temporarily
            continue

        # Normal city packing
        if total_area + current_area > MAX_ft2:
            if gdf_accum is not None:
                merged_file_list.append(gdf_accum)
            gdf_accum = None
            total_area = 0
            last_centroid = None

        if gdf_accum is None:
            gdf_accum = current_gdf.copy()
        else:
            gdf_accum = pd.concat([gdf_accum, current_gdf], ignore_index=True)

        total_area += current_area

    # append leftover normal cities
    if gdf_accum is not None:
        merged_file_list.append(gdf_accum)

    # === Combine last chunks greedily with smaller files ===
    for chunk in last_chunks:
        chunk_area = chunk["area_ft2"].sum()
        placed = False
        for i, merged in enumerate(merged_file_list):
            merged_area = merged["area_ft2"].sum()
            if merged_area + chunk_area <= MAX_ft2:
                merged_file_list[i] = pd.concat([merged, chunk], ignore_index=True)
                placed = True
                break
        if not placed:
            merged_file_list.append(chunk)  # new file if cannot fit

    return merged_file_list

# %%
splits = split_gpkg_greedy_by_city(result)
split_dict = turn_list_to_dict(splits)

# 4️⃣ Compute and print total area for each split
for key, gdf in split_dict.items():
    total_ft2 = gdf['area_ft2'].sum()
    print(f"Total area of {key}: ({total_ft2:,.0f} ft²)")
# Out:
# Total area of file1: (19,969,925 ft²)
# Total area of file2: (19,967,066 ft²)
# Total area of file3: (19,965,001 ft²)
# Total area of file4: (19,967,392 ft²)
# Total area of file5: (19,836,473 ft²)
# Total area of file6: (16,610,799 ft²)

# %%
import os
import geopandas as gpd
import folium
from shapely.ops import unary_union
from shapely.geometry import Polygon, MultiPolygon
import re
from shapely.validation import make_valid


# Folder to save GeoJSONs
output_folder = "West_Virginia_700k(6)"
os.makedirs(output_folder, exist_ok=True)

colors = [
    "red","blue","blue","purple","orange","darkred","lightred","black",
    "darkblue","darkgreen","cadetblue","pink","lightblue","green",
    "gray","black"
]

def sanitize_filename(name):
    # replace anything not alphanumeric or underscore with underscore
    return re.sub(r"[^\w\-\. ]", "_", name)


# Build base map from overall bounds
all_bounds = [gdf.to_crs(4326).total_bounds for gdf in split_dict.values()]
minx = min(b[0] for b in all_bounds)
miny = min(b[1] for b in all_bounds)
maxx = max(b[2] for b in all_bounds)
maxy = max(b[3] for b in all_bounds)

m = folium.Map(
    location=[(miny+maxy)/2, (minx+maxx)/2],
    zoom_start=7
)

def make_style(color):
    return lambda feat: {
        "fillColor": color,
        "color": color,
        "weight": 2,
        "fillOpacity": 0.45
    }

for i, (key, gdf) in enumerate(split_dict.items()):


    gdf4326 = gdf.to_crs(4326)
    # Fix invalid geometries
    gdf4326["geometry"] = gdf4326["geometry"].apply(make_valid)


    # --- Largest city name ---
    city_areas = gdf.groupby("city_name")["area_ft2"].sum()
    largest_city = city_areas.idxmax()

    # --- List of all cities ---
    all_cities = sorted(gdf["city_name"].unique())
    all_cities_str = ", ".join(all_cities)

    # --- Merge into single MultiPolygon ---
    merged_geom = unary_union(gdf4326.geometry)

    # If it's a geometry collection, extract only polygons
    if merged_geom.geom_type == "GeometryCollection":
        polys = [g for g in merged_geom.geoms if isinstance(g, (Polygon, MultiPolygon))]
        merged_geom = unary_union(polys)

    merged_gdf = gpd.GeoDataFrame(
        {
            "largest_city": [largest_city],
            "all_cities": [all_cities_str],
            "total_area_ft2": [gdf["area_ft2"].sum()]
        },
        geometry=[merged_geom],
        crs=4326
    )

    # --- Save GeoJSON ---
    safe_name = sanitize_filename(largest_city)
    filepath = os.path.join(output_folder, f"{safe_name}.geojson")
    merged_gdf.to_file(filepath, driver="GeoJSON")


    # --- Add ALL layers to folium ---
    color = colors[i % len(colors)]
    layer_name = f"{i+1}. {largest_city}"
    

    gj = folium.GeoJson(
        merged_gdf,
        name=layer_name,
        tooltip=f"{largest_city}<br>{gdf['area_ft2'].sum():,.0f} ft²",
        style_function=make_style(color),
    )

    gj.add_to(m)

# Final map adjustments
m.fit_bounds([[miny, minx], [maxy, maxx]])
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f95bf8137c0a1c050beeb0e2924686bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f95bf8137c0a1c050beeb0e2924686bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f95bf8137c0a1c050beeb0e2924686bd = L.map(
#                 &quot;map_f95bf8137c0a1c050beeb0e2924686bd&quot;,
#                 {
#                     center: [38.93385067641498, -80.16115437331472],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a1fb063cb80114604632ddd6b6cdf53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a1fb063cb80114604632ddd6b6cdf53.addTo(map_f95bf8137c0a1c050beeb0e2924686bd);
#
#
#         function geo_json_9b7b4a011009a2b138ecb23099033a33_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.45, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_9b7b4a011009a2b138ecb23099033a33_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json