# %%
import geopandas as gpd
import pandas as pd
from shapely.ops import unary_union
import os
import math

# %%
# This notebook takes in multiple files in gpkg format, and merges them up to 20 million square feet. 
# Once that limit is reached, it will begin the process again, until running out of polygons to merge.

# %%
# Create a gdf dictionary where {key = name representation: value = gdf file}
def create_gdf_dict(filename_list):
    gdf_dict = {}
    
    # Get the name mapped to each gdf in dictionary form
    for file_str in filename_list:
        current_gpd = gpd.read_file(file_str)
        base_name = os.path.splitext(file_str)[0]
        
        gdf_dict[base_name] = current_gpd

    return gdf_dict

# Turn the final list into a dictionary for easy access and name representation
def turn_list_to_dict(merged_list):
    list_to_dict = {}
    name = "file"
    count = 1
    
    for gdf in merged_list:
        list_to_dict[name + str(count)] = gdf
        count += 1

    return list_to_dict

# Generates the utm value for the given shape file
def auto_utm(gdf):
    gdf = gdf.to_crs("EPSG:4326")
    
    # Get centroid coordinates (in lon/lat)
    cent = gdf.to_crs(3857).centroid.to_crs(gdf.crs)
    lon = cent.x.mean()
    lat = cent.y.mean()

    # Compute UTM zone
    zone = int((lon + 180) / 6) + 1
    if lat >= 0:
        epsg = 32600 + zone  # Northern Hemisphere
    else:
        epsg = 32700 + zone  # Southern Hemisphere

    return epsg

# retrieve the total area (in meters) of a multipolygon shape file
def check_total_area(gpkg_file):
    epsg = auto_utm(gpkg_file)
    
    gdf = gpkg_file.to_crs(epsg=epsg)
    gdf["area"] = gdf.geometry.area
    gdf = gdf.sort_values("area", ascending=False)
    total_area = 0

    for idx, row in gdf.iterrows():
        total_area += row["area"]

    print(gdf.crs)

    return total_area

# %%
gdf= gpd.read_file("unified_geopackages_just_unified/state_17_unified.gpkg")
gdf = gdf.set_crs(4326, allow_override=True)
result = gdf[["city_name", "geometry"]].copy()

# %%
import geopandas as gpd
import pandas as pd
from shapely.ops import unary_union

gpkg = "unified_geopackages_updated/state_55_unified.gpkg"

# -----------------------------
# Load layers with forced CRS
# -----------------------------
def load_layer(name):
    gdf = gpd.read_file(gpkg, layer=name)
    gdf = gdf.set_crs(4326, allow_override=True)
    return gdf[["city_name", "geometry"]]

gdf_indoor = load_layer("indoor_gyms")
gdf_parkserve = load_layer("parkserve_geom")
gdf_osm = load_layer("osm_geom")

# -----------------------------
# Merge all 3 layers on city_name
# Outer join keeps all cities from any layer
# -----------------------------
merged = (
    gdf_indoor.rename(columns={"geometry": "geom_indoor"})
    .merge(gdf_parkserve.rename(columns={"geometry": "geom_parkserve"}), on="city_name", how="outer")
    .merge(gdf_osm.rename(columns={"geometry": "geom_osm"}), on="city_name", how="outer")
)

for col in ["geom_indoor", "geom_parkserve", "geom_osm"]:
    merged[col] = merged[col].apply(lambda g: make_valid(g) if g is not None else None)
# -----------------------------
# Union geometries city-by-city
# -----------------------------
union_geoms = []

for idx, row in merged.iterrows():
    geoms = []

    for col in ["geom_indoor", "geom_parkserve", "geom_osm"]:
        geom = row[col]
        if geom is not None and not geom.is_empty:
            geoms.append(geom)

    if len(geoms) == 0:
        union_geoms.append(None)
    else:
        union_geoms.append(unary_union(geoms))

merged["geometry"] = union_geoms

# -----------------------------
# Final output
# -----------------------------
result = merged[["city_name", "geometry"]].copy()
result = gpd.GeoDataFrame(result, geometry="geometry", crs="EPSG:4326")

print(result)
# Out:
#        city_name                                           geometry
# 0     Abbotsford  MULTIPOLYGON (((-90.322 44.947, -90.322 44.948...
# 1         Abrams  MULTIPOLYGON (((-88.058 44.778, -88.058 44.779...
# 2          Adams  MULTIPOLYGON (((-89.818 43.959, -89.817 43.959...
# 3          Adell  POLYGON ((-87.948 43.618, -87.951 43.618, -87....
# 4         Albany  MULTIPOLYGON (((-89.438 42.707, -89.438 42.707...
# ..           ...                                                ...
# 704     Woodruff  MULTIPOLYGON (((-89.697 45.894, -89.697 45.894...
# 705    Woodville  MULTIPOLYGON (((-92.284 44.943, -92.284 44.943...
# 706  Wrightstown  MULTIPOLYGON (((-88.155 44.314, -88.155 44.314...
# 707      Wyocena  POLYGON ((-89.308 43.495, -89.308 43.495, -89....
# 708    Yorkville  MULTIPOLYGON (((-87.993 42.685, -87.993 42.685...
#
# [709 rows x 2 columns]

# %%
import pandas as pd
import math

MAX_AREA_FT2 = 700_000

def split_gpkg_greedy_by_city(
    gdf,
    MAX_ft2=19_970_000
):
    # Remove invalid geometries
    gdf = gdf[~gdf.geometry.is_empty & gdf.geometry.notnull()].copy()

    # Safe CRS → UTM
    target_crs = auto_utm(gdf)
    gdf = gdf.to_crs(target_crs)

    #Explode each city polygon and filter
    gdf = gdf.explode(index_parts=False).reset_index(drop=True)
    gdf["area_ft2"] = gdf.geometry.area * 10.76391

    gdf = gdf[gdf["area_ft2"] <= MAX_AREA_FT2]

    # Group by city where possible
    city_col = "city_name"
    city_groups = {city: group for city, group in gdf.groupby(city_col)}
    city_areas = {city: group["area_ft2"].sum() for city, group in city_groups.items()} 

    # Safe centroids
    city_centroids = {}
    for city, group in city_groups.items():
        try:
            centroid = group.geometry.union_all().centroid
        except Exception:
            centroid = group.geometry.centroid.iloc[0]
        city_centroids[city] = centroid

    merged_file_list = []
    gdf_accum = None
    total_area = 0
    remaining_cities = list(city_groups.keys())
    last_centroid = None

    last_chunks = []  # <-- store last chunks of oversized cities

    while remaining_cities:

        # Pick next city
        if last_centroid is None:
            candidates = sorted(
                remaining_cities,
                key=lambda c: (city_centroids[c].y, city_centroids[c].x)
            )
            next_city = candidates[0]
        else:
            candidates = [
                c for c in remaining_cities
                if total_area + city_areas[c] <= MAX_ft2
            ]
            if not candidates:
                candidates = remaining_cities
            next_city = min(
                candidates,
                key=lambda c: city_centroids[c].distance(last_centroid)
            )

        current_gdf = city_groups.pop(next_city)
        current_area = city_areas.pop(next_city)
        last_centroid = city_centroids.pop(next_city)
        remaining_cities.remove(next_city)

        # Oversized city handling
        if current_area > MAX_ft2:
            #To maximize area per file, we group the large files first and then fill the gaps with the smaller parks
            exploded_sorted = current_gdf.sort_values("area_ft2", ascending=False)

            chunk_accum = []
            chunk_total = 0
            chunk_idx = 1

            for _, row in exploded_sorted.iterrows():
                row_gdf = gpd.GeoDataFrame(row.to_frame().T, geometry='geometry', crs=current_gdf.crs)

                if chunk_total + row["area_ft2"] > MAX_ft2:
                    if chunk_accum:
                        chunk_gdf = gpd.GeoDataFrame(pd.concat(chunk_accum, ignore_index=True),
                                                     geometry='geometry', crs=current_gdf.crs)
                        chunk_gdf["city_name"] = f"{next_city}_{chunk_idx}"
                        merged_file_list.append(chunk_gdf)
                        chunk_idx += 1
                    chunk_accum = [row_gdf]
                    chunk_total = row["area_ft2"]
                else:
                    chunk_accum.append(row_gdf)
                    chunk_total += row["area_ft2"]

            # === Keep last chunk separate ===
            if chunk_accum:
                last_chunk_gdf = gpd.GeoDataFrame(pd.concat(chunk_accum, ignore_index=True),
                                                  geometry='geometry', crs=current_gdf.crs)
                last_chunk_gdf["city_name"] = f"{next_city}_{chunk_idx}"
                last_chunks.append(last_chunk_gdf)  # store temporarily
            continue

        # Normal city packing
        if total_area + current_area > MAX_ft2:
            if gdf_accum is not None:
                merged_file_list.append(gdf_accum)
            gdf_accum = None
            total_area = 0
            last_centroid = None

        if gdf_accum is None:
            gdf_accum = current_gdf.copy()
        else:
            gdf_accum = pd.concat([gdf_accum, current_gdf], ignore_index=True)

        total_area += current_area

    # append leftover normal cities
    if gdf_accum is not None:
        merged_file_list.append(gdf_accum)

    # === Combine last chunks greedily with smaller files ===
    for chunk in last_chunks:
        chunk_area = chunk["area_ft2"].sum()
        placed = False
        for i, merged in enumerate(merged_file_list):
            merged_area = merged["area_ft2"].sum()
            if merged_area + chunk_area <= MAX_ft2:
                merged_file_list[i] = pd.concat([merged, chunk], ignore_index=True)
                placed = True
                break
        if not placed:
            merged_file_list.append(chunk)  # new file if cannot fit

    return merged_file_list

# %%
splits = split_gpkg_greedy_by_city(result)
split_dict = turn_list_to_dict(splits)

# 4️⃣ Compute and print total area for each split
for key, gdf in split_dict.items():
    total_ft2 = gdf['area_ft2'].sum()
    print(f"Total area of {key}: ({total_ft2:,.0f} ft²)")
# Out:
# Total area of file1: (19,968,057 ft²)
# Total area of file2: (19,967,522 ft²)
# Total area of file3: (19,963,765 ft²)
# Total area of file4: (19,964,250 ft²)
# Total area of file5: (19,966,898 ft²)
# Total area of file6: (19,950,031 ft²)
# Total area of file7: (19,967,929 ft²)
# Total area of file8: (19,969,428 ft²)
# Total area of file9: (16,629,705 ft²)
# Total area of file10: (17,740,329 ft²)
# Total area of file11: (19,967,470 ft²)
# Total area of file12: (19,942,128 ft²)
# Total area of file13: (19,963,934 ft²)
# Total area of file14: (19,957,468 ft²)
# Total area of file15: (19,963,417 ft²)
# Total area of file16: (19,962,092 ft²)
# Total area of file17: (19,630,571 ft²)
# Total area of file18: (19,965,091 ft²)
# Total area of file19: (19,962,179 ft²)
# Total area of file20: (19,949,683 ft²)
# Total area of file21: (19,680,872 ft²)
# Total area of file22: (19,949,140 ft²)
# Total area of file23: (19,957,613 ft²)
# Total area of file24: (19,784,526 ft²)
# Total area of file25: (19,925,267 ft²)
# Total area of file26: (19,969,820 ft²)
# Total area of file27: (19,941,384 ft²)
# Total area of file28: (19,946,096 ft²)
# Total area of file29: (19,969,025 ft²)
# Total area of file30: (19,953,662 ft²)
# Total area of file31: (19,966,381 ft²)
# Total area of file32: (19,925,764 ft²)
# Total area of file33: (19,924,100 ft²)
# Total area of file34: (19,927,590 ft²)
# Total area of file35: (19,950,825 ft²)
# Total area of file36: (19,955,125 ft²)
# Total area of file37: (19,968,688 ft²)
# Total area of file38: (19,916,381 ft²)
# Total area of file39: (19,914,844 ft²)
# Total area of file40: (19,938,230 ft²)
# Total area of file41: (19,956,177 ft²)
# Total area of file42: (19,927,780 ft²)
# Total area of file43: (19,967,946 ft²)
# Total area of file44: (19,912,474 ft²)
# Total area of file45: (19,950,601 ft²)
# Total area of file46: (19,897,272 ft²)
# Total area of file47: (19,926,101 ft²)
# Total area of file48: (19,967,521 ft²)
# Total area of file49: (19,906,409 ft²)
# Total area of file50: (19,940,222 ft²)
# Total area of file51: (19,962,508 ft²)
# Total area of file52: (19,949,869 ft²)
# Total area of file53: (19,889,343 ft²)
# Total area of file54: (19,889,648 ft²)
# Total area of file55: (19,893,169 ft²)
# Total area of file56: (19,834,987 ft²)
# Total area of file57: (8,826,740 ft²)
# Total area of file58: (18,663,938 ft²)
# Total area of file59: (17,523,275 ft²)

# %%
import os
import geopandas as gpd
import folium
from shapely.ops import unary_union
from shapely.geometry import Polygon, MultiPolygon
import re
from shapely.validation import make_valid


# Folder to save GeoJSONs
output_folder = "Wisconsin_700k(59)"
os.makedirs(output_folder, exist_ok=True)

colors = [
    "red","blue","blue","purple","orange","darkred","lightred","black",
    "darkblue","darkgreen","cadetblue","pink","lightblue","green",
    "gray","black"
]

def sanitize_filename(name):
    # replace anything not alphanumeric or underscore with underscore
    return re.sub(r"[^\w\-\. ]", "_", name)


# Build base map from overall bounds
all_bounds = [gdf.to_crs(4326).total_bounds for gdf in split_dict.values()]
minx = min(b[0] for b in all_bounds)
miny = min(b[1] for b in all_bounds)
maxx = max(b[2] for b in all_bounds)
maxy = max(b[3] for b in all_bounds)

m = folium.Map(
    location=[(miny+maxy)/2, (minx+maxx)/2],
    zoom_start=7
)

def make_style(color):
    return lambda feat: {
        "fillColor": color,
        "color": color,
        "weight": 2,
        "fillOpacity": 0.45
    }

for i, (key, gdf) in enumerate(split_dict.items()):


    gdf4326 = gdf.to_crs(4326)
    # Fix invalid geometries
    gdf4326["geometry"] = gdf4326["geometry"].apply(make_valid)


    # --- Largest city name ---
    city_areas = gdf.groupby("city_name")["area_ft2"].sum()
    largest_city = city_areas.idxmax()

    # --- List of all cities ---
    all_cities = sorted(gdf["city_name"].unique())
    all_cities_str = ", ".join(all_cities)

    # --- Merge into single MultiPolygon ---
    merged_geom = unary_union(gdf4326.geometry)

    # If it's a geometry collection, extract only polygons
    if merged_geom.geom_type == "GeometryCollection":
        polys = [g for g in merged_geom.geoms if isinstance(g, (Polygon, MultiPolygon))]
        merged_geom = unary_union(polys)

    merged_gdf = gpd.GeoDataFrame(
        {
            "largest_city": [largest_city],
            "all_cities": [all_cities_str],
            "total_area_ft2": [gdf["area_ft2"].sum()]
        },
        geometry=[merged_geom],
        crs=4326
    )

    # --- Save GeoJSON ---
    safe_name = sanitize_filename(largest_city)
    filepath = os.path.join(output_folder, f"{safe_name}.geojson")
    merged_gdf.to_file(filepath, driver="GeoJSON")


    # --- Add ALL layers to folium ---
    color = colors[i % len(colors)]
    layer_name = f"{i+1}. {largest_city}"
    

    gj = folium.GeoJson(
        merged_gdf,
        name=layer_name,
        tooltip=f"{largest_city}<br>{gdf['area_ft2'].sum():,.0f} ft²",
        style_function=make_style(color),
    )

    gj.add_to(m)

# Final map adjustments
m.fit_bounds([[miny, minx], [maxy, maxx]])
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0960c2d3bf399386eee3cddd7396e0ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0960c2d3bf399386eee3cddd7396e0ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0960c2d3bf399386eee3cddd7396e0ea = L.map(
#                 &quot;map_0960c2d3bf399386eee3cddd7396e0ea&quot;,
#                 {
#                     center: [44.676594712987054, -89.93851844009083],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_041a9c234a8cb12c433509fcafdfb53b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_041a9c234a8cb12c433509fcafdfb53b.addTo(map_0960c2d3bf399386eee3cddd7396e0ea);
#
#
#         function geo_json_e4d25b55a26ec05f6e57177acebdc858_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.45, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_e4d25b55a26ec05f6e57177acebdc858_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_e4d25b55a26ec05f6e57177acebdc858 = L.geoJson(null, {
#                 onEachFeature: geo_json_e4d25b55a26ec05f6e57177acebdc858_onEachFeature,
#
#                 style: geo_json_e4d25b55a26ec05f6e57177acebdc858_styler,
#             ...{
# }
#         });
#
#         function geo_json_e4d25b55a26ec05f6e57177acebdc858_add (data) {
#             geo_json_e4d25b55a26ec05f6e57177acebdc858
#                 .addData(data);
#         }
#             geo_json_e4d25b55a26ec05f6e57177acebdc858_add({&quot;bbox&quot;: [-91.3942977, 42.49833608841982, -88.07391760000002, 45.00147339999999], &quot;features&quot;: [{&quot;bbox&quot;: [-91.3942977, 42.49833608841982, -88.07391760000002, 45.00147339999999], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-88.32613120966701, 42.49833989612686], [-88.32729809606826, 42.49833608841982], [-88.32729619343647, 42.49866921388878], [-88.32637296247964, 42.49868063496135], [-88.32613120966701, 42.49833989612686]]], [[[-88.33417538228781, 42.50637504216808], [-88.33417538228781, 42.50637763553243], [-88.3339209905436, 42.50637671366959], [-88.3332382, 42.50638119999999], [-88.332183, 42.505476800000004], [-88.3314379, 42.504838199999995], [-88.3320473, 42.50402259999999], [-88.3321406, 42.503864899999996], [-88.3320477, 42.50318959999999], [-88.33224, 42.50273939999998], [-88.3325657, 42.50229360000001], [-88.3326818, 42.502303599999976], [-88.3332772, 42.50304169999999], [-88.3333017, 42.503745799999976], [-88.33331075365703, 42.5037460027575], [-88.33417538228781, 42.503747861832665], [-88.33417538228781, 42.50584656112434], [-88.3341818, 42.506374999999984], [-88.33417538228781, 42.50637504216808]]], [[[-88.3398625, 42.50716299999998], [-88.3397921, 42.50715919999998], [-88.3397845, 42.50723539999999], [-88.3395054, 42.50722019999999], [-88.3395421, 42.506855800000004], [-88.3398138, 42.50687059999999], [-88.3398121, 42.506887299999995], [-88.3398898, 42.50689150000001], [-88.3398625, 42.50716299999998]]], [[[-88.28276143405765, 42.539108402896794], [-88.28222063494059, 42.53928210165555], [-88.28279793448307, 42.53987820246192], [-88.28185883580582, 42.53984530053296], [-88.28185483600696, 42.54016280031651], [-88.28076933755212, 42.5401537980704], [-88.28061483706192, 42.5389855985031], [-88.28269223408074, 42.53898560283402], [-88.28276143405765, 42.539108402896794]]], [[[-88.25767966699794, 42.53280205344377], [-88.25795386657425, 42.53275895404943], [-88.25832046607731, 42.532845154794664], [-88.2590784651393, 42.5332039562511], [-88.25898906534695, 42.53336055598867], [-88.2587425657637, 42.533474055411084], [-88.25810176675341, 42.53357855399756], [-88.25753796760338, 42.53362845277351], [-88.25751107484798, 42.53352321439631], [-88.25750206169147, 42.53352204783804], [-88.25748398132576, 42.533521081349534], [-88.2574691672303, 42.53352142950475], [-88.25746979539656, 42.53336167711921], [-88.25735926752968, 42.532929152702344], [-88.25767966699794, 42.53280205344377]]], [[[-88.2783344, 42.62413939999998], [-88.2792124, 42.62387650000001], [-88.2793478, 42.624230499999996], [-88.2787594, 42.62445379999998], [-88.2783344, 42.62413939999998]]], [[[-88.2752445, 42.6251371], [-88.276479, 42.625132], [-88.276156, 42.625938000000005], [-88.2751552, 42.62594230000001], [-88.2752445, 42.6251371]]], [[[-88.27002699686928, 42.663139362333546], [-88.26851625064866, 42.66314720470085], [-88.26851625
